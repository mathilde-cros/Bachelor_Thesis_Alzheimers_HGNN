# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pkl
import wandb

import torch
from torch_geometric.data import InMemoryDataset
from torch_geometric.utils import from_networkx

import networkx as nx
from networkx.convert_matrix import from_numpy_array

import functions as f
from functions import dict_to_array, normalize_array
import models as m
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
os.environ['WANDB_NOTEBOOK_NAME']="GCN_2Class.ipynb"

# %%
# Loading the time series
time_series_list = f.load_time_series()
time_series_df_list = f.list_of_df_of_time_series(time_series_list)

# %%
# Loading the pearson correlation matrices
corr_matrix_list = f.corr_matrix_paths()['pearson']
print(corr_matrix_list)
# Example patient
path = f'ADNI_full/corr_matrices/corr_matrix_pearson/{corr_matrix_list[0]}'
corr_matrix_patient = np.loadtxt(path, delimiter=',')
print(corr_matrix_patient)
# Out:
# ['patient_136_S_4517.csv', 'patient_130_S_4468.csv', 'patient_002_S_4654.csv', 'patient_002_S_4251.csv', 'patient_013_S_5171.csv', 'patient_130_S_2391.csv', 'patient_031_S_4947.csv', 'patient_100_S_5102.csv', 'patient_012_S_5121.csv', 'patient_053_S_5287.csv', 'patient_002_S_1261.csv', 'patient_018_S_4313.csv', 'patient_130_S_4641.csv', 'patient_012_S_4188.csv', 'patient_002_S_4521.csv', 'patient_130_S_4250.csv', 'patient_031_S_4005.csv', 'patient_130_S_5006.csv', 'patient_006_S_4363.csv', 'patient_012_S_4012.csv', 'patient_031_S_4149.csv', 'patient_031_S_4029.csv', 'patient_013_S_4917.csv', 'patient_129_S_4287.csv', 'patient_130_S_4730.csv', 'patient_129_S_0778.csv', 'patient_031_S_4203.csv', 'patient_013_S_4268.csv', 'patient_053_S_0919.csv', 'patient_002_S_4447.csv', 'patient_012_S_4987.csv', 'patient_018_S_4868.csv', 'patient_100_S_4556.csv', 'patient_100_S_5106.csv', 'patient_130_S_5175.csv', 'patient_130_S_4294.csv', 'patient_053_S_5296.csv', 'patient_031_S_4474.csv', 'patient_129_S_4396.csv', 'patient_012_S_5157.csv', 'patient_129_S_4369.csv', 'patient_013_S_2324.csv', 'patient_013_S_4580.csv', 'patient_013_S_4595.csv', 'patient_130_S_4542.csv', 'patient_006_S_4515.csv', 'patient_129_S_4220.csv', 'patient_002_S_0295.csv', 'patient_018_S_5250.csv', 'patient_012_S_5195.csv', 'patient_136_S_4993.csv', 'patient_130_S_5258.csv', 'patient_006_S_4449.csv', 'patient_002_S_0685.csv', 'patient_130_S_4352.csv', 'patient_018_S_4399.csv', 'patient_053_S_4661.csv', 'patient_018_S_4400.csv', 'patient_130_S_4971.csv', 'patient_006_S_5153.csv', 'patient_012_S_4128.csv', 'patient_002_S_4225.csv', 'patient_018_S_2138.csv', 'patient_002_S_4219.csv', 'patient_013_S_5071.csv', 'patient_031_S_4476.csv', 'patient_130_S_5059.csv', 'patient_053_S_5208.csv', 'patient_130_S_4343.csv', 'patient_136_S_4189.csv', 'patient_019_S_4680.csv', 'patient_100_S_2351.csv', 'patient_013_S_4579.csv', 'patient_136_S_0107.csv', 'patient_013_S_4791.csv', 'patient_019_S_4252.csv', 'patient_018_S_4809.csv', 'patient_019_S_4285.csv', 'patient_002_S_2043.csv', 'patient_013_S_4395.csv', 'patient_019_S_4293.csv', 'patient_100_S_4469.csv', 'patient_130_S_4817.csv', 'patient_018_S_5240.csv', 'patient_129_S_4422.csv', 'patient_006_S_4713.csv', 'patient_002_S_4746.csv', 'patient_019_S_5012.csv', 'patient_002_S_4237.csv', 'patient_018_S_4349.csv', 'patient_031_S_2018.csv', 'patient_031_S_4496.csv', 'patient_130_S_4990.csv', 'patient_130_S_4984.csv', 'patient_018_S_2133.csv', 'patient_130_S_4589.csv', 'patient_002_S_4213.csv', 'patient_136_S_4408.csv', 'patient_013_S_4985.csv', 'patient_002_S_1155.csv', 'patient_002_S_4171.csv', 'patient_031_S_2233.csv', 'patient_130_S_4417.csv', 'patient_012_S_4094.csv', 'patient_130_S_4415.csv', 'patient_006_S_4867.csv', 'patient_100_S_4512.csv', 'patient_012_S_4849.csv', 'patient_018_S_4597.csv', 'patient_031_S_4721.csv', 'patient_013_S_4616.csv', 'patient_131_S_5148.csv', 'patient_002_S_2073.csv', 'patient_031_S_2022.csv', 'patient_006_S_4679.csv', 'patient_018_S_5262.csv', 'patient_130_S_4982.csv', 'patient_136_S_4433.csv', 'patient_012_S_4643.csv', 'patient_002_S_4229.csv', 'patient_002_S_0729.csv', 'patient_012_S_5213.csv', 'patient_053_S_2396.csv', 'patient_019_S_5019.csv', 'patient_013_S_1186.csv', 'patient_130_S_4997.csv', 'patient_031_S_4042.csv', 'patient_010_S_4345.csv', 'patient_006_S_4485.csv', 'patient_041_S_5026.csv', 'patient_130_S_4405.csv', 'patient_053_S_5202.csv', 'patient_130_S_4605.csv', 'patient_129_S_4371.csv', 'patient_019_S_4477.csv', 'patient_053_S_2357.csv', 'patient_013_S_5137.csv', 'patient_002_S_4799.csv', 'patient_002_S_5256.csv', 'patient_053_S_4813.csv', 'patient_012_S_4545.csv', 'patient_002_S_0413.csv', 'patient_031_S_4032.csv', 'patient_031_S_4218.csv', 'patient_002_S_4264.csv', 'patient_002_S_4270.csv', 'patient_019_S_5242.csv', 'patient_006_S_0731.csv', 'patient_019_S_4835.csv', 'patient_130_S_4925.csv', 'patient_053_S_4557.csv', 'patient_130_S_2373.csv', 'patient_002_S_5230.csv', 'patient_006_S_4153.c ...
# [[ 1.          0.62126391  0.40501965 ... -0.07884583  0.07740484
#   -0.36456412]
#  [ 0.62126391  1.         -0.0033939  ...  0.02684759  0.0412815
#   -0.1746839 ]
#  [ 0.40501965 -0.0033939   1.         ... -0.17088309 -0.15494682
#   -0.09877457]
#  ...
#  [-0.07884583  0.02684759 -0.17088309 ...  1.          0.39632277
#    0.00382471]
#  [ 0.07740484  0.0412815  -0.15494682 ...  0.39632277  1.
#    0.35172939]
#  [-0.36456412 -0.1746839  -0.09877457 ...  0.00382471  0.35172939
#    1.        ]]

# %%
# Loading the diagnostic labels
diagnostic_label_all = np.loadtxt('ADNI_full/diagnostic_label.csv', dtype=str, delimiter=',')

# %%
def filter_group(group):
    df = pd.read_csv('ADNI_FULL/patient_info.csv')
    labels = df['Research Group']
    label_idx_list = [i for i in range(len(labels)) if labels[i] == group]
    return label_idx_list

# %%
#binary classification
cn = filter_group('CN')
ad = filter_group('AD')
bin_idx = sorted(cn + ad)
corr_matrices = [corr_matrix_list[i] for i in bin_idx]
diagnostic_label = [diagnostic_label_all[i] for i in bin_idx]
for i in range(len(diagnostic_label)):
    if diagnostic_label[i] == 'CN':
        diagnostic_label[i] = 0
    elif diagnostic_label[i] == 'AD':
        diagnostic_label[i] = 1
    else:
        print('Error: incorrect label')

# %%
assert len(diagnostic_label) == len(corr_matrices)

# %%
# Defining a class to preprocess raw data into a format suitable for training Graph Neural Networks (GNNs).
## With the possibility of assigning weight to edges, adding the age feature, sex feature, and matrixe profiling.

class Raw_to_Graph_2Class(InMemoryDataset):
    def __init__(self, root, threshold, method, weight=False, age=False, sex=False, matrixprofile=False, transform=None, pre_transform=None):
        self.threshold = threshold
        self.method = method
        self.weight = weight
        self.age = age
        self.sex = sex
        self.matrixprofile = matrixprofile
        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def processed_file_names(self):
        return ['data.pt']

    # This function is used to process the raw data into a format suitable for GNNs, by constructing graphs out of the connectivity matrices.
    def process(self):
        graphs=[]
        for patient_idx, patient_matrix in enumerate(corr_matrices):
            path = f'ADNI_full/corr_matrices/corr_matrix_{self.method}/{patient_matrix}'
            corr_matrix = np.loadtxt(path, delimiter=',')
            # Here ROIs stands for Regions of Interest
            nbr_ROIs = corr_matrix.shape[0]
            edge_matrix = np.zeros((nbr_ROIs,nbr_ROIs))
            for j in range(nbr_ROIs):
                for k in range(nbr_ROIs):
                    # Here we are using the absolute value of each element of the correlation matrix, as the corr coeff is in the range [-1,1].
                    if np.abs(corr_matrix[j,k]) < self.threshold:
                        edge_matrix[j,k] = 0
                    else:
                        if self.weight:
                            # Here we assign the absolute value of the correlation coefficient as the edge weight.
                            edge_matrix[j,k] = corr_matrix[j,k]
                        else:
                            # Here we assign 1 as the edge weight, i.e. regardless of the the absolute value of the correlation coefficient.
                            edge_matrix[j,k] = 1

            # Create a NetworkX graph from the edge matrix
            NetworkX_graph = from_numpy_array(edge_matrix)

            # Compute the degree, betweenness centrality, clustering coefficient, local efficiency for each node of the graph and the global efficiency of the graph
            degree_dict = dict(NetworkX_graph.degree())
            between_central_dict = nx.betweenness_centrality(NetworkX_graph)
            cluster_coeff_dict = nx.clustering(NetworkX_graph)
            global_eff = nx.global_efficiency(NetworkX_graph)
            local_eff_dict = {}
            for node in NetworkX_graph.nodes():
                subgraph_neighb = NetworkX_graph.subgraph(NetworkX_graph.neighbors(node))
                if subgraph_neighb.number_of_nodes() > 1:
                    efficiency = nx.global_efficiency(subgraph_neighb)
                else:
                    efficiency = 0.0
                local_eff_dict[node] = efficiency

            # Convert the degree, betweenness centrality, local efficiency, clustering coefficient and ratio of local to global efficiency dictionaries to NumPy arrays then normalize them
            degree_array = dict_to_array(degree_dict)
            degree_array_norm = normalize_array(degree_array)

            between_central_array = dict_to_array(between_central_dict)
            between_central_array_norm = normalize_array(between_central_array)

            local_efficiency_array = dict_to_array(local_eff_dict)
            local_eff_array_norm = normalize_array(local_efficiency_array)

            ratio_local_global_array = dict_to_array(local_eff_dict) / global_eff
            ratio_local_global_array_norm = normalize_array(ratio_local_global_array)

            cluster_coeff_array = dict_to_array(cluster_coeff_dict)
            cluster_coeff_array_norm = normalize_array(cluster_coeff_array)

            # Initializing an array for the graph features
            x_array = np.stack([degree_array_norm, between_central_array_norm, local_eff_array_norm, cluster_coeff_array_norm, ratio_local_global_array_norm], axis=-1)
            x_array = x_array.astype(np.float32)
            
            if self.matrixprofile:
                path = f'ADNI_full/matrix_profiles/matrix_profile_{self.method}/{patient_matrix}'
                with open(path, "rb") as fl:
                  patient_dict = pkl.load(fl)
                # combine dimensions
                features = np.array(patient_dict['mp']).reshape(len(patient_dict['mp']),-1)
                features = features.astype(np.float32)
                x_array = np.concatenate((x_array, features), axis=-1)

            # Concatenate the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to form a single feature vector
            x = torch.tensor(x_array, dtype=torch.float)

            # Create a Pytorch Geometric Data object from the NetworkX
            graph_data = from_networkx(NetworkX_graph)
            ## The feature matrix of the graph is the degree, betweenness centrality, local efficiency, clustering coefficient and ratio of local to global efficiency of each node
            graph_data.x = x
            ## The target/output variable that we want to predict is the diagnostic label of the patient
            graph_data.y = float(diagnostic_label[patient_idx])
            graphs.append(graph_data)

        data, slices = self.collate(graphs)
        torch.save((data, slices), self.processed_paths[0])

# %%
# Doing some parameter gridsearch to find the best hyperparameters
from sklearn.model_selection import ParameterGrid

# Building the graphs
threshold = 0.5
age = False
sex = False
matrixprofile = True
weight = True
if matrixprofile:
    in_channels = 461 + int(age) + int(sex)
else:
    in_channels = 5 + int(age) + int(sex)
method = 'pearson'

root = f'Raw_to_graph_2Class/ADNI_T_{threshold}_M_{method}_W{weight}_A{age}_S{sex}_MP{matrixprofile}'
dataset = Raw_to_Graph_2Class(root=root, threshold=threshold, method=method, weight=weight, sex=sex, age=age, matrixprofile=matrixprofile)
f.dataset_features_and_stats(dataset, diagnostic_label)

# Creating the train, validation and test sets
train_loader, valid_loader, test_loader, nbr_classes = f.create_train_test_valid(dataset)

param_grid = {
    'learning_rate': [0.001, 0.0001],
    'hidden_channels': [128, 64],
    'num_layers': [3, 2, 1],
    'dropout_rate': [0.2, 0.1, 0.0],
    'weight_decay': [0.001, 0.0001]
}
# param_grid = {
#     'learning_rate': [0.0001, 0.001],
#     'hidden_channels': [64, 128],
#     'num_layers': [1, 2, 3],
#     'dropout_rate': [0.0, 0.1, 0.2],
#     'weight_decay': [0.0001, 0.001]
# }


# Create combinations of hyperparameters
param_combinations = ParameterGrid(param_grid)
n_epochs = 800
# Train using each combination
for params in param_combinations:
    if matrixprofile:
        filename = f'2Class_Models/GCN_Models_MP/threshold_{threshold}/lr{params["learning_rate"]}_hc{params["hidden_channels"]}_nl{params["num_layers"]}_d{params["dropout_rate"]}_epochs{n_epochs}_wdecay{params["weight_decay"]}_w{weight}.png'
    else:
        filename = f'2Class_Models/GCN_Models/threshold_{threshold}/lr{params["learning_rate"]}_hc{params["hidden_channels"]}_nl{params["num_layers"]}_d{params["dropout_rate"]}_epochs{n_epochs}_wdecay{params["weight_decay"]}_w{weight}.png'
    if os.path.exists(filename):
        pass
    else:
        parameters = [params['learning_rate'], params['hidden_channels'], params['num_layers'], params['dropout_rate']]
        model = m.GCN(in_channels=in_channels, hidden_channels=parameters[1], out_channels=nbr_classes, num_layers=parameters[2], dropout=parameters[3], nbr_classes=nbr_classes)
        criterion = torch.nn.CrossEntropyLoss()
        if 'weight_decay' not in params.keys():
            w_decay = 0
        else:
            w_decay = params['weight_decay']
        optimizer = torch.optim.Adam(model.parameters(), lr=parameters[0], weight_decay=w_decay)
        train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = m.train_GCN(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing=True, n_epochs=800)
# Out:
# Dataset: Raw_to_Graph_2Class(78):
# ====================
# Number of graphs: 78
# Weighted: True
# Threshold: 0.5
# Correlation Method: pearson
# Number of features: 461
# Number of classes: 2
#
# Data(edge_index=[2, 1116], weight=[1116], x=[116, 461], y=[1], num_nodes=116)
# =============================================================
# Number of nodes: 116
# Number of edges: 1116
# Average node degree: 9.62
# Has isolated nodes: True
# Has self-loops: True
# Is undirected: True
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# Number of classes: 2
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/data/in_memory_dataset.py:284: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find GCN_2Class.ipynb.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# wandb: Currently logged in as: mathilde-cros (alzheimers-cl). Use `wandb login --relogin` to force relogin
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/Users/mathilde/Documents/Bachelor-Thesis-Alzheimers-HGNN/wandb/run-20240313_040430-yh1nvhqh</code>
# Syncing run <strong><a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/yh1nvhqh' target="_blank">serene-surf-4828</a></strong> to <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN</a>
#  View run at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/yh1nvhqh' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/yh1nvhqh</a>
# Epoch 1/800
# Train Loss: 2.8676, Validation Loss: 4.1185
# Train Accuracy: 0.5052, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 2/800
# Train Loss: 2.8927, Validation Loss: 2.0624
# Train Accuracy: 0.4375, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 3/800
# Train Loss: 0.9435, Validation Loss: 1.1635
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 4/800
# Train Loss: 0.9985, Validation Loss: 0.9582
# Train Accuracy: 0.5000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 5/800
# Train Loss: 0.8814, Validation Loss: 0.6638
# Train Accuracy: 0.4010, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 6/800
# Train Loss: 0.8279, Validation Loss: 0.7451
# Train Accuracy: 0.5781, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 7/800
# Train Loss: 0.5937, Validation Loss: 0.8021
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 8/800
# Train Loss: 0.8558, Validation Loss: 0.7054
# Train Accuracy: 0.3646, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 9/800
# Train Loss: 0.6445, Validation Loss: 0.6864
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 10/800
# Train Loss: 0.6413, Validation Loss: 0.7138
# Train Accuracy: 0.6146, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 11/800
# Train Loss: 0.7191, Validation Loss: 0.6829
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 12/800
# Train Loss: 0.7096, Validation Loss: 0.6932
# Train Accuracy: 0.5417, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 13/800
# Train Loss: 0.6811, Validation Loss: 0.7644
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 14/800
# Train Loss: 0.6825, Validation Loss: 0.6981
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 15/800
# Train Loss: 0.6428, Validation Loss: 0.6862
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 16/800
# Train Loss: 0.6604, Validation Loss: 0.6777
# Train Accuracy: 0.6406, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 17/800
# Train Loss: 0.6749, Validation Loss: 0.6827
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 18/800
# Train Loss: 0.6973, Validation Loss: 0.6787
# Train Accuracy: 0.5573, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 19/800
# Train Loss: 0.6582, Validation Loss: 0.6936
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 20/800
# Train Loss: 0.6916, Validation Loss: 0.6828
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 21/800
# Train Loss: 0.6904, Validation Loss: 0.6859
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 22/800
# Train Loss: 0.6436, Validation Loss: 0.6785
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 23/800
# Train Loss: 0.6413, Validation Loss: 0.7099
# Train Accuracy: 0.6719, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 24/800
# Train Loss: 0.6748, Validation Loss: 0.6802
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 25/800
# Train Loss: 0.6888, Validation Loss: 0.6992
# Train Accuracy: 0.5573, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 26/800
# Train Loss: 0.7637, Validation Loss: 0.6863
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 27/800
# Train Loss: 0.7614, Validation Loss: 0.6972
# Train Accuracy: 0.4271, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 28/800
# Train Loss: 0.6016, Validation Loss: 0.8712
# Train Accuracy: 0.6458, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 29/800
# Train Loss: 0.7521, Validation Loss: 0.7319
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 30/800
# Train Loss: 0.6875, Validation Loss: 0.7007
# Train Accuracy: 0.5781, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 31/800
# Train Loss: 0.6481, Validation Loss: 0.8434
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 32/800
# Train Loss: 0.7042, Validation Loss: 0.7090
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 33/800
# Train Loss: 0.7070, Validation Loss: 0.7032
# Train Accuracy: 0.5104, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 34/800
# Train Loss: 0.7041, Validation Loss: 0.7616
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 35/800
# Train Loss: 0.6679, Validation Loss: 0.6906
# Train Accuracy: 0.6094, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 36/800
# Train Loss: 0.6632, Validation Loss: 0.6933
# Train Accuracy: 0.6458, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 37/800
# Train Loss: 0.6551, Validation Loss: 0.7315
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 38/800
# Train Loss: 0.6512, Validation Loss: 0.7008
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 39/800
# Train Loss: 0.6490, Validation Loss: 0.6944
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 40/800
# Train Loss: 0.6551, Validation Loss: 0.7005
# Train Accuracy: 0.5938, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 41/800
# Train Loss: 0.6408, Validation Loss: 0.6960
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 42/800
# Train Loss: 0.6513, Validation Loss: 0.6953
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 43/800
# Train Loss: 0.6294, Validation Loss: 0.6971
# Train Accuracy: 0.6042, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 44/800
# Train Loss: 0.6855, Validation Loss: 0.6895
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 45/800
# Train Loss: 0.6337, Validation Loss: 0.6868
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 46/800
# Train Loss: 0.6066, Validation Loss: 0.7166
# Train Accuracy: 0.7083, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 47/800
# Train Loss: 0.6605, Validation Loss: 0.6984
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 48/800
# Train Loss: 0.6585, Validation Loss: 0.6902
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 49/800
# Train Loss: 0.6346, Validation Loss: 0.7072
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 50/800
# Train Loss: 0.6261, Validation Loss: 0.6951
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 51/800
# Train Loss: 0.6469, Validation Loss: 0.6974
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 52/800
# Train Loss: 0.6576, Validation Loss: 0.6924
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 53/800
# Train Loss: 0.5842, Validation Loss: 0.7382
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 54/800
# Train Loss: 0.6431, Validation Loss: 0.6780
# Train Accuracy: 0.6094, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 55/800
# Train Loss: 0.6439, Validation Loss: 0.6823
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 56/800
# Train Loss: 0.6532, Validation Loss: 0.7138
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 57/800
# Train Loss: 0.6447, Validation Loss: 0.6887
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 58/800
# Train Loss: 0.6390, Validation Loss: 0.7007
# Train Accuracy: 0.5417, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 59/800
# Train Loss: 0.6760, Validation Loss: 0.7191
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 60/800
# Train Loss: 0.6394, Validation Loss: 0.7054
# Train Accuracy: 0.6094, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 61/800
# Train Loss: 0.6242, Validation Loss: 0.7045
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 62/800
# Train Loss: 0.6340, Validation Loss: 0.7181
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 63/800
# Train Loss: 0.6027, Validation Loss: 0.7806
# Train Accuracy: 0.7344, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 64/800
# Train Loss: 0.6352, Validation Loss: 0.7515
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 65/800
# Train Loss: 0.6426, Validation Loss: 0.7049
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 66/800
# Train Loss: 0.6115, Validation Loss: 0.6982
# Train Accuracy: 0.6510, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 67/800
# Train Loss: 0.6726, Validation Loss: 0.7322
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 68/800
# Train Loss: 0.6642, Validation Loss: 0.7472
# Train Accuracy: 0.5417, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 69/800
# Train Loss: 0.6358, Validation Loss: 0.7135
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 70/800
# Train Loss: 0.6931, Validation Loss: 0.6995
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 71/800
# Train Loss: 0.7473, Validation Loss: 0.7162
# Train Accuracy: 0.3438, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 72/800
# Train Loss: 0.6589, Validation Loss: 0.7496
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 73/800
# Train Loss: 0.6719, Validation Loss: 0.7122
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 74/800
# Train Loss: 0.6763, Validation Loss: 0.6972
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 75/800
# Train Loss: 0.6732, Validation Loss: 0.6957
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 76/800
# Train Loss: 0.6300, Validation Loss: 0.7057
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 77/800
# Train Loss: 0.6878, Validation Loss: 0.7280
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 78/800
# Train Loss: 0.6691, Validation Loss: 0.7037
# Train Accuracy: 0.4948, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 79/800
# Train Loss: 0.6149, Validation Loss: 0.8033
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 80/800
# Train Loss: 0.6622, Validation Loss: 0.6928
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 81/800
# Train Loss: 0.6394, Validation Loss: 0.7056
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 82/800
# Train Loss: 0.6419, Validation Loss: 0.6913
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 83/800
# Train Loss: 0.6702, Validation Loss: 0.6932
# Train Accuracy: 0.5521, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 84/800
# Train Loss: 0.6387, Validation Loss: 0.6917
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 85/800
# Train Loss: 0.6269, Validation Loss: 0.7052
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 86/800
# Train Loss: 0.6319, Validation Loss: 0.7315
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 87/800
# Train Loss: 0.7513, Validation Loss: 0.6874
# Train Accuracy: 0.3698, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 88/800
# Train Loss: 0.6950, Validation Loss: 0.7474
# Train Accuracy: 0.5469, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 89/800
# Train Loss: 0.6301, Validation Loss: 0.7087
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 90/800
# Train Loss: 0.6755, Validation Loss: 0.6969
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 91/800
# Train Loss: 0.6457, Validation Loss: 0.6884
# Train Accuracy: 0.6146, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 92/800
# Train Loss: 0.6117, Validation Loss: 0.7430
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 93/800
# Train Loss: 0.6141, Validation Loss: 0.6875
# Train Accuracy: 0.6354, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 94/800
# Train Loss: 0.6189, Validation Loss: 0.6964
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 95/800
# Train Loss: 0.6847, Validation Loss: 0.6931
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 96/800
# Train Loss: 0.6245, Validation Loss: 0.6963
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 97/800
# Train Loss: 0.6314, Validation Loss: 0.7242
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 98/800
# Train Loss: 0.6505, Validation Loss: 0.7077
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 99/800
# Train Loss: 0.6485, Validation Loss: 0.7088
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 100/800
# Train Loss: 0.6596, Validation Loss: 0.7322
# Train Accuracy: 0.5990, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 101/800
# Train Loss: 0.5965, Validation Loss: 0.7132
# Train Accuracy: 0.6510, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 102/800
# Train Loss: 0.6317, Validation Loss: 0.6961
# Train Accuracy: 0.6042, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 103/800
# Train Loss: 0.5698, Validation Loss: 0.7436
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 104/800
# Train Loss: 0.7099, Validation Loss: 0.6919
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 105/800
# Train Loss: 0.6912, Validation Loss: 0.6987
# Train Accuracy: 0.4688, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 106/800
# Train Loss: 0.7216, Validation Loss: 0.7028
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 107/800
# Train Loss: 0.6969, Validation Loss: 0.6983
# Train Accuracy: 0.5104, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 108/800
# Train Loss: 0.7269, Validation Loss: 0.7632
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 109/800
# Train Loss: 0.6530, Validation Loss: 0.7008
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 110/800
# Train Loss: 0.6480, Validation Loss: 0.7676
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 111/800
# Train Loss: 0.6615, Validation Loss: 0.7217
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 112/800
# Train Loss: 0.6549, Validation Loss: 0.6869
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 113/800
# Train Loss: 0.6600, Validation Loss: 0.7111
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 114/800
# Train Loss: 0.6544, Validation Loss: 0.6840
# Train Accuracy: 0.6354, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 115/800
# Train Loss: 0.6505, Validation Loss: 0.6959
# Train Accuracy: 0.6979, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 116/800
# Train Loss: 0.6861, Validation Loss: 0.6814
# Train Accuracy: 0.6094, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 117/800
# Train Loss: 0.6757, Validation Loss: 0.6908
# Train Accuracy: 0.5365, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 118/800
# Train Loss: 0.6616, Validation Loss: 0.6863
# Train Accuracy: 0.6667, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 119/800
# Train Loss: 0.7023, Validation Loss: 0.6990
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 120/800
# Train Loss: 0.6704, Validation Loss: 0.6883
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 121/800
# Train Loss: 0.7130, Validation Loss: 0.7012
# Train Accuracy: 0.5052, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 122/800
# Train Loss: 0.6760, Validation Loss: 0.7586
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 123/800
# Train Loss: 0.6897, Validation Loss: 0.6994
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 124/800
# Train Loss: 0.6426, Validation Loss: 0.7447
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 125/800
# Train Loss: 0.6491, Validation Loss: 0.7093
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 126/800
# Train Loss: 0.6529, Validation Loss: 0.7263
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 127/800
# Train Loss: 0.6394, Validation Loss: 0.7086
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 128/800
# Train Loss: 0.6314, Validation Loss: 0.7130
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 129/800
# Train Loss: 0.7565, Validation Loss: 0.6925
# Train Accuracy: 0.5573, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 130/800
# Train Loss: 0.7741, Validation Loss: 0.7026
# Train Accuracy: 0.3542, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 131/800
# Train Loss: 0.7552, Validation Loss: 0.7692
# Train Accuracy: 0.4427, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 132/800
# Train Loss: 0.6334, Validation Loss: 0.7125
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 133/800
# Train Loss: 0.6338, Validation Loss: 0.7226
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 134/800
# Train Loss: 0.6344, Validation Loss: 0.7181
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 135/800
# Train Loss: 0.6273, Validation Loss: 0.7146
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 136/800
# Train Loss: 0.7077, Validation Loss: 0.7012
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 137/800
# Train Loss: 0.6506, Validation Loss: 0.6932
# Train Accuracy: 0.6510, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 138/800
# Train Loss: 0.6289, Validation Loss: 0.7102
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 139/800
# Train Loss: 0.7225, Validation Loss: 0.7140
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 140/800
# Train Loss: 0.6507, Validation Loss: 0.7022
# Train Accuracy: 0.6875, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 141/800
# Train Loss: 0.6393, Validation Loss: 0.7193
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 142/800
# Train Loss: 0.6641, Validation Loss: 0.7128
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 143/800
# Train Loss: 0.6449, Validation Loss: 0.6895
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 144/800
# Train Loss: 0.6472, Validation Loss: 0.6902
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 145/800
# Train Loss: 0.6254, Validation Loss: 0.6932
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 146/800
# Train Loss: 0.6226, Validation Loss: 0.6978
# Train Accuracy: 0.6094, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 147/800
# Train Loss: 0.6405, Validation Loss: 0.7007
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 148/800
# Train Loss: 0.7132, Validation Loss: 0.7211
# Train Accuracy: 0.5417, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 149/800
# Train Loss: 0.6368, Validation Loss: 0.7124
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 150/800
# Train Loss: 0.6162, Validation Loss: 0.7976
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 151/800
# Train Loss: 0.6632, Validation Loss: 0.7104
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 152/800
# Train Loss: 0.6474, Validation Loss: 0.7000
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 153/800
# Train Loss: 0.6363, Validation Loss: 0.7011
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 154/800
# Train Loss: 0.6163, Validation Loss: 0.7373
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 155/800
# Train Loss: 0.6061, Validation Loss: 0.7041
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 156/800
# Train Loss: 0.6677, Validation Loss: 0.6944
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 157/800
# Train Loss: 0.6757, Validation Loss: 0.6946
# Train Accuracy: 0.5260, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 158/800
# Train Loss: 0.6845, Validation Loss: 0.7571
# Train Accuracy: 0.5521, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 159/800
# Train Loss: 0.6522, Validation Loss: 0.7104
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 160/800
# Train Loss: 0.6618, Validation Loss: 0.6973
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 161/800
# Train Loss: 0.6419, Validation Loss: 0.7068
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 162/800
# Train Loss: 0.6948, Validation Loss: 0.7156
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 163/800
# Train Loss: 0.6189, Validation Loss: 0.6913
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 164/800
# Train Loss: 0.6815, Validation Loss: 0.6964
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 165/800
# Train Loss: 0.6483, Validation Loss: 0.6945
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 166/800
# Train Loss: 0.6302, Validation Loss: 0.6988
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 167/800
# Train Loss: 0.6004, Validation Loss: 0.7213
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 168/800
# Train Loss: 0.6399, Validation Loss: 0.7164
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 169/800
# Train Loss: 0.6131, Validation Loss: 0.7034
# Train Accuracy: 0.6094, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 170/800
# Train Loss: 0.6058, Validation Loss: 0.7081
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 171/800
# Train Loss: 0.5569, Validation Loss: 1.1649
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 172/800
# Train Loss: 0.7345, Validation Loss: 0.6956
# Train Accuracy: 0.4792, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 173/800
# Train Loss: 0.6564, Validation Loss: 0.7106
# Train Accuracy: 0.5260, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 174/800
# Train Loss: 0.7198, Validation Loss: 0.7143
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 175/800
# Train Loss: 0.7360, Validation Loss: 0.7226
# Train Accuracy: 0.3906, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 176/800
# Train Loss: 0.7065, Validation Loss: 0.7466
# Train Accuracy: 0.5469, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 177/800
# Train Loss: 0.6272, Validation Loss: 0.7195
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 178/800
# Train Loss: 0.6629, Validation Loss: 0.6939
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 179/800
# Train Loss: 0.6330, Validation Loss: 0.6909
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 180/800
# Train Loss: 0.6137, Validation Loss: 0.7297
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 181/800
# Train Loss: 0.6079, Validation Loss: 0.7478
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 182/800
# Train Loss: 0.6334, Validation Loss: 0.7100
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 183/800
# Train Loss: 0.6352, Validation Loss: 0.6985
# Train Accuracy: 0.6198, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 184/800
# Train Loss: 0.5917, Validation Loss: 0.7327
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 185/800
# Train Loss: 0.6754, Validation Loss: 0.7046
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 186/800
# Train Loss: 0.6878, Validation Loss: 0.7024
# Train Accuracy: 0.5260, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 187/800
# Train Loss: 0.6491, Validation Loss: 0.7141
# Train Accuracy: 0.6302, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 188/800
# Train Loss: 0.6220, Validation Loss: 0.7729
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 189/800
# Train Loss: 0.6775, Validation Loss: 0.7309
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 190/800
# Train Loss: 0.6457, Validation Loss: 0.6919
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 191/800
# Train Loss: 0.6563, Validation Loss: 0.6923
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 192/800
# Train Loss: 0.6510, Validation Loss: 0.7022
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 193/800
# Train Loss: 0.6285, Validation Loss: 0.7039
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 194/800
# Train Loss: 0.6094, Validation Loss: 0.6970
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 195/800
# Train Loss: 0.6303, Validation Loss: 0.6953
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 196/800
# Train Loss: 0.6303, Validation Loss: 0.7034
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 197/800
# Train Loss: 0.6134, Validation Loss: 0.7050
# Train Accuracy: 0.6823, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 198/800
# Train Loss: 0.6483, Validation Loss: 0.7137
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 199/800
# Train Loss: 0.6230, Validation Loss: 0.7021
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 200/800
# Train Loss: 0.6142, Validation Loss: 0.6973
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 201/800
# Train Loss: 0.5974, Validation Loss: 0.7058
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 202/800
# Train Loss: 0.6333, Validation Loss: 0.7218
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 203/800
# Train Loss: 0.6094, Validation Loss: 0.7494
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 204/800
# Train Loss: 0.6178, Validation Loss: 0.7582
# Train Accuracy: 0.6927, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 205/800
# Train Loss: 0.6745, Validation Loss: 0.7065
# Train Accuracy: 0.5104, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 206/800
# Train Loss: 0.5774, Validation Loss: 0.7700
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 207/800
# Train Loss: 0.6433, Validation Loss: 0.7565
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 208/800
# Train Loss: 0.6136, Validation Loss: 0.6978
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 209/800
# Train Loss: 0.5996, Validation Loss: 0.6968
# Train Accuracy: 0.7031, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 210/800
# Train Loss: 0.6575, Validation Loss: 0.7118
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 211/800
# Train Loss: 0.6020, Validation Loss: 0.7159
# Train Accuracy: 0.6562, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 212/800
# Train Loss: 0.6728, Validation Loss: 0.7046
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 213/800
# Train Loss: 0.6359, Validation Loss: 0.7044
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 214/800
# Train Loss: 0.6018, Validation Loss: 0.6929
# Train Accuracy: 0.6406, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 215/800
# Train Loss: 0.6019, Validation Loss: 0.7026
# Train Accuracy: 0.6302, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 216/800
# Train Loss: 0.6589, Validation Loss: 0.6999
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 217/800
# Train Loss: 0.5991, Validation Loss: 0.7153
# Train Accuracy: 0.7812, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 218/800
# Train Loss: 0.5950, Validation Loss: 0.7076
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 219/800
# Train Loss: 0.5839, Validation Loss: 0.6995
# Train Accuracy: 0.6615, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.8750
# Epoch 220/800
# Train Loss: 0.6358, Validation Loss: 0.7055
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 221/800
# Train Loss: 0.5661, Validation Loss: 0.7279
# Train Accuracy: 0.7240, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 222/800
# Train Loss: 0.8608, Validation Loss: 0.7483
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 223/800
# Train Loss: 0.7753, Validation Loss: 0.7803
# Train Accuracy: 0.5052, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 224/800
# Train Loss: 0.6824, Validation Loss: 0.7396
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 225/800
# Train Loss: 0.6467, Validation Loss: 0.8104
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 226/800
# Train Loss: 0.6442, Validation Loss: 0.6891
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 227/800
# Train Loss: 0.6706, Validation Loss: 0.7576
# Train Accuracy: 0.6042, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 228/800
# Train Loss: 0.7387, Validation Loss: 0.7615
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 229/800
# Train Loss: 0.6687, Validation Loss: 0.7041
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 230/800
# Train Loss: 0.6562, Validation Loss: 0.7095
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 231/800
# Train Loss: 0.6658, Validation Loss: 0.6940
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 232/800
# Train Loss: 0.6519, Validation Loss: 0.6956
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 233/800
# Train Loss: 0.6756, Validation Loss: 0.7054
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 234/800
# Train Loss: 0.6539, Validation Loss: 0.7016
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 235/800
# Train Loss: 0.6484, Validation Loss: 0.6935
# Train Accuracy: 0.7552, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 236/800
# Train Loss: 0.6523, Validation Loss: 0.7266
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 237/800
# Train Loss: 0.6543, Validation Loss: 0.6954
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 238/800
# Train Loss: 0.6477, Validation Loss: 0.6944
# Train Accuracy: 0.6562, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 239/800
# Train Loss: 0.6945, Validation Loss: 0.6946
# Train Accuracy: 0.5781, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 240/800
# Train Loss: 0.6313, Validation Loss: 0.6945
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 241/800
# Train Loss: 0.6371, Validation Loss: 0.7152
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 242/800
# Train Loss: 0.6517, Validation Loss: 0.6926
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 243/800
# Train Loss: 0.6498, Validation Loss: 0.6908
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 244/800
# Train Loss: 0.6416, Validation Loss: 0.7207
# Train Accuracy: 0.5625, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 245/800
# Train Loss: 0.6356, Validation Loss: 0.6908
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 246/800
# Train Loss: 0.6294, Validation Loss: 0.6934
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 247/800
# Train Loss: 0.6848, Validation Loss: 0.6951
# Train Accuracy: 0.5521, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 248/800
# Train Loss: 0.6688, Validation Loss: 0.6893
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 249/800
# Train Loss: 0.6494, Validation Loss: 0.6921
# Train Accuracy: 0.5677, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 250/800
# Train Loss: 0.6873, Validation Loss: 0.6907
# Train Accuracy: 0.5625, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 251/800
# Train Loss: 0.7376, Validation Loss: 0.7317
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 252/800
# Train Loss: 0.6678, Validation Loss: 0.7038
# Train Accuracy: 0.6198, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 253/800
# Train Loss: 0.6645, Validation Loss: 0.6972
# Train Accuracy: 0.5469, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 254/800
# Train Loss: 0.6386, Validation Loss: 0.7000
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 255/800
# Train Loss: 0.6209, Validation Loss: 0.7140
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 256/800
# Train Loss: 0.6597, Validation Loss: 0.7065
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 257/800
# Train Loss: 0.6517, Validation Loss: 0.6936
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 258/800
# Train Loss: 0.6346, Validation Loss: 0.6927
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 259/800
# Train Loss: 0.6627, Validation Loss: 0.6923
# Train Accuracy: 0.5990, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 260/800
# Train Loss: 0.6269, Validation Loss: 0.6920
# Train Accuracy: 0.6406, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 261/800
# Train Loss: 0.6161, Validation Loss: 0.6923
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 262/800
# Train Loss: 0.6656, Validation Loss: 0.6920
# Train Accuracy: 0.6094, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 263/800
# Train Loss: 0.6694, Validation Loss: 0.6926
# Train Accuracy: 0.5885, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 264/800
# Train Loss: 0.6706, Validation Loss: 0.7107
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 265/800
# Train Loss: 0.6472, Validation Loss: 0.7075
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 266/800
# Train Loss: 0.6257, Validation Loss: 0.6947
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 267/800
# Train Loss: 0.6433, Validation Loss: 0.6958
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 268/800
# Train Loss: 0.6819, Validation Loss: 0.6946
# Train Accuracy: 0.5417, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 269/800
# Train Loss: 0.6403, Validation Loss: 0.7067
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 270/800
# Train Loss: 0.6601, Validation Loss: 0.7044
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 271/800
# Train Loss: 0.6770, Validation Loss: 0.7034
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 272/800
# Train Loss: 0.6315, Validation Loss: 0.7003
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 273/800
# Train Loss: 0.6661, Validation Loss: 0.6940
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 274/800
# Train Loss: 0.6279, Validation Loss: 0.7037
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 275/800
# Train Loss: 0.6265, Validation Loss: 0.7017
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 276/800
# Train Loss: 0.6716, Validation Loss: 0.7195
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 277/800
# Train Loss: 0.6289, Validation Loss: 0.6962
# Train Accuracy: 0.7031, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 278/800
# Train Loss: 0.5989, Validation Loss: 0.7587
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 279/800
# Train Loss: 0.7011, Validation Loss: 0.7318
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 280/800
# Train Loss: 0.6099, Validation Loss: 0.6949
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 281/800
# Train Loss: 0.6545, Validation Loss: 0.6924
# Train Accuracy: 0.5521, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 282/800
# Train Loss: 0.6424, Validation Loss: 0.7004
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 283/800
# Train Loss: 0.6498, Validation Loss: 0.7194
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 284/800
# Train Loss: 0.6336, Validation Loss: 0.7152
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 285/800
# Train Loss: 0.6408, Validation Loss: 0.6912
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 286/800
# Train Loss: 0.6355, Validation Loss: 0.6965
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 287/800
# Train Loss: 0.6364, Validation Loss: 0.6959
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 288/800
# Train Loss: 0.6022, Validation Loss: 0.7486
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 289/800
# Train Loss: 0.6304, Validation Loss: 0.7124
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 290/800
# Train Loss: 0.6231, Validation Loss: 0.6854
# Train Accuracy: 0.6406, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 291/800
# Train Loss: 0.6081, Validation Loss: 0.7709
# Train Accuracy: 0.7656, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 292/800
# Train Loss: 0.7382, Validation Loss: 0.7537
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 293/800
# Train Loss: 0.6360, Validation Loss: 0.7087
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 294/800
# Train Loss: 0.7133, Validation Loss: 0.6993
# Train Accuracy: 0.4635, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 295/800
# Train Loss: 0.6397, Validation Loss: 0.7009
# Train Accuracy: 0.6771, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 296/800
# Train Loss: 0.6442, Validation Loss: 0.6926
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 297/800
# Train Loss: 0.6473, Validation Loss: 0.6967
# Train Accuracy: 0.5781, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 298/800
# Train Loss: 0.6368, Validation Loss: 0.7111
# Train Accuracy: 0.6042, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 299/800
# Train Loss: 0.6113, Validation Loss: 0.7087
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 300/800
# Train Loss: 0.6663, Validation Loss: 0.6912
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 301/800
# Train Loss: 0.6307, Validation Loss: 0.6924
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 302/800
# Train Loss: 0.6280, Validation Loss: 0.7336
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 303/800
# Train Loss: 0.6431, Validation Loss: 0.6871
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 304/800
# Train Loss: 0.6261, Validation Loss: 0.6912
# Train Accuracy: 0.6667, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 305/800
# Train Loss: 0.6212, Validation Loss: 0.6939
# Train Accuracy: 0.7552, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 306/800
# Train Loss: 0.6034, Validation Loss: 0.6991
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 307/800
# Train Loss: 0.6262, Validation Loss: 0.7016
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 308/800
# Train Loss: 0.7844, Validation Loss: 0.6845
# Train Accuracy: 0.5573, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 309/800
# Train Loss: 0.6613, Validation Loss: 0.7293
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 310/800
# Train Loss: 0.6478, Validation Loss: 0.6924
# Train Accuracy: 0.5677, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 311/800
# Train Loss: 0.5824, Validation Loss: 0.7685
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 312/800
# Train Loss: 0.5884, Validation Loss: 0.7136
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 313/800
# Train Loss: 0.6240, Validation Loss: 0.6892
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 314/800
# Train Loss: 0.6269, Validation Loss: 0.6896
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 315/800
# Train Loss: 0.6084, Validation Loss: 0.6867
# Train Accuracy: 0.6823, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 316/800
# ...
# Max Validation Accuracy: 0.8750
# Epoch 790/800
# Train Loss: 0.6517, Validation Loss: 0.6978
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 791/800
# Train Loss: 0.6401, Validation Loss: 0.6997
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 792/800
# Train Loss: 0.6488, Validation Loss: 0.6998
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 793/800
# Train Loss: 0.6021, Validation Loss: 0.6985
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 794/800
# Train Loss: 0.6096, Validation Loss: 0.6983
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 795/800
# Train Loss: 0.6800, Validation Loss: 0.7006
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 796/800
# Train Loss: 0.6370, Validation Loss: 0.6987
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 797/800
# Train Loss: 0.6558, Validation Loss: 0.6965
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 798/800
# Train Loss: 0.6467, Validation Loss: 0.6969
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 799/800
# Train Loss: 0.6609, Validation Loss: 0.6970
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Epoch 800/800
# Train Loss: 0.6624, Validation Loss: 0.6981
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.8750
# Test Accuracy: 0.5
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Finishing last run (ID:yh1nvhqh) before initializing another...
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Max Valid Accuracy</td><td>▁███████████████████████████████████████</td></tr><tr><td>Test Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Train Accuracy</td><td>▁▅▅▆▄▄▆▅▅▆▆▄▅▆▆▆▄▅▇▆▅▆▆▄▅▅▅▄▆▄▇▅▂▄▇█▅▅▅▅</td></tr><tr><td>Train Loss</td><td>█▅▅▅▆▆▅▅▅▄▄▅▅▅▄▄▅▄▄▄▅▅▅▆▅▅▅▆▄▅▃▄▆▅▃▁▅▅▅▅</td></tr><tr><td>Validation Accuracy</td><td>▅█▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▁▁▅▅▅▅█▅▅▅▅▅</td></tr><tr><td>Validation Loss</td><td>▁▁▁▂▂▁▁▁▁▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▁▁█▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Max Valid Accuracy</td><td>0.875</td></tr><tr><td>Test Accuracy</td><td>0.5</td></tr><tr><td>Train Accuracy</td><td>0.63542</td></tr><tr><td>Train Loss</td><td>0.66245</td></tr><tr><td>Validation Accuracy</td><td>0.5</td></tr><tr><td>Validation Loss</td><td>0.69812</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">serene-surf-4828</strong> at: <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/yh1nvhqh' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/yh1nvhqh</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240313_040430-yh1nvhqh/logs</code>
# Successfully finished last run (ID:yh1nvhqh). Initializing new run:<br/>
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/Users/mathilde/Documents/Bachelor-Thesis-Alzheimers-HGNN/wandb/run-20240313_041050-zo3e52me</code>
# Syncing run <strong><a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/zo3e52me' target="_blank">vital-breeze-4835</a></strong> to <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN</a>
#  View run at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/zo3e52me' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/zo3e52me</a>
# Epoch 1/800
# Train Loss: 3.2782, Validation Loss: 1.2071
# Train Accuracy: 0.4688, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 2/800
# Train Loss: 1.1542, Validation Loss: 0.8923
# Train Accuracy: 0.5521, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 3/800
# Train Loss: 0.6815, Validation Loss: 0.8701
# Train Accuracy: 0.6458, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 4/800
# Train Loss: 0.9634, Validation Loss: 1.1320
# Train Accuracy: 0.4271, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 5/800
# Train Loss: 1.0236, Validation Loss: 0.7102
# Train Accuracy: 0.6615, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.5000
# Epoch 6/800
# Train Loss: 0.7011, Validation Loss: 0.7146
# Train Accuracy: 0.5208, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.5000
# Epoch 7/800
# Train Loss: 0.7801, Validation Loss: 0.7202
# Train Accuracy: 0.6250, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 8/800
# Train Loss: 0.7440, Validation Loss: 0.7068
# Train Accuracy: 0.4479, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 9/800
# Train Loss: 0.8274, Validation Loss: 0.7461
# Train Accuracy: 0.5833, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 10/800
# Train Loss: 0.7245, Validation Loss: 0.7840
# Train Accuracy: 0.4896, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 11/800
# Train Loss: 0.6168, Validation Loss: 0.8861
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 12/800
# Train Loss: 0.7900, Validation Loss: 0.7055
# Train Accuracy: 0.5833, Validation Accuracy: 0.3750
# Max Validation Accuracy: 0.5000
# Epoch 13/800
# Train Loss: 0.7677, Validation Loss: 0.7918
# Train Accuracy: 0.4375, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 14/800
# Train Loss: 0.6632, Validation Loss: 0.7492
# Train Accuracy: 0.6406, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# /Users/mathilde/Documents/Bachelor-Thesis-Alzheimers-HGNN/functions.py:449: DeprecationWarning: invalid escape sequence '\m'
#   """The hypergraph convolutional operator from the `"Hypergraph Convolution
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 59
#      57     w_decay = params['weight_decay']
#      58 optimizer = torch.optim.Adam(model.parameters(), lr=parameters[0], weight_decay=w_decay)
# ---> 59 train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = m.train_GCN(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing=True, n_epochs=800)
#
# File ~/Documents/Bachelor-Thesis-Alzheimers-HGNN/models.py:79, in train_GCN(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing, n_epochs)
#      77 for epoch in range(n_epochs):
#      78     if testing:
# ---> 79         train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = f.epochs_training(model, optimizer, criterion, train_loader, valid_loader, test_loader, testing, test_accuracy, train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy)
#      80         wandb.log({"Train Loss": train_losses[-1], "Train Accuracy": train_accuracies[-1], "Validation Loss": valid_losses[-1], "Validation Accuracy": valid_accuracies[-1], "Max Valid Accuracy": max_valid_accuracy, "Test Accuracy": test_accuracy})
#      81     else:
#
# File ~/Documents/Bachelor-Thesis-Alzheimers-HGNN/functions.py:648, in epochs_training(model, optimizer, criterion, train_loader, valid_loader, test_loader, testing, test_accuracy, train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy)
#     646 for data in valid_loader:
#     647     target = data.y.clone().detach().long()
# --> 648     out = model(data.x, data.edge_index, data.batch)
#     649     valid_loss += criterion(out, target)
#     650     valid_accuracy += quick_accuracy(out, target)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/Bachelor-Thesis-Alzheimers-HGNN/models.py:36, in GCN.forward(self, x, edge_index, batch)
#      33 def forward(self, x, edge_index, batch):
#      34     # xs = []
#      35     for conv in self.convs:
# ---> 36         x = conv(x, edge_index)
#      37         x = F.relu(x)
#      38         if self.dropout > 0:
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/conv/gcn_conv.py:244, in GCNConv.forward(self, x, edge_index, edge_weight)
#     241 x = self.lin(x)
#     243 # propagate_type: (x: Tensor, edge_weight: OptTensor)
# --> 244 out = self.propagate(edge_index, x=x, edge_weight=edge_weight,
#     245                      size=None)
#     247 if self.bias is not None:
#     248     out = out + self.bias
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/conv/message_passing.py:480, in MessagePassing.propagate(self, edge_index, size, **kwargs)
#     477     if res is not None:
#     478         aggr_kwargs = res[0] if isinstance(res, tuple) else res
# --> 480 out = self.aggregate(out, **aggr_kwargs)
#     482 for hook in self._aggregate_forward_hooks.values():
#     483     res = hook(self, (aggr_kwargs, ), out)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/conv/message_passing.py:604, in MessagePassing.aggregate(self, inputs, index, ptr, dim_size)
#     591 def aggregate(self, inputs: Tensor, index: Tensor,
#     592               ptr: Optional[Tensor] = None,
#     593               dim_size: Optional[int] = None) -> Tensor:
#     594     r"""Aggregates messages from neighbors as
#     595     :math:`\bigoplus_{j \in \mathcal{N}(i)}`.
#     596
#    (...)
#     602     as specified in :meth:`__init__` by the :obj:`aggr` argument.
#     603     """
# --> 604     return self.aggr_module(inputs, index, ptr=ptr, dim_size=dim_size,
#     605                             dim=self.node_dim)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/experimental.py:115, in disable_dynamic_shapes.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def wrapper(*args, **kwargs):
#     114     if not is_experimental_mode_enabled('disable_dynamic_shapes'):
# --> 115         return func(*args, **kwargs)
#     117     for required_arg in required_args:
#     118         index = required_args_pos[required_arg]
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/aggr/base.py:125, in Aggregation.__call__(self, x, index, ptr, dim_size, dim, **kwargs)
#     122     dim_size = int(index.max()) + 1 if index.numel() > 0 else 0
#     124 try:
# --> 125     return super().__call__(x, index=index, ptr=ptr, dim_size=dim_size,
#     126                             dim=dim, **kwargs)
#     127 except (IndexError, RuntimeError) as e:
#     128     if index is not None:
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/aggr/basic.py:22, in SumAggregation.forward(self, x, index, ptr, dim_size, dim)
#      19 def forward(self, x: Tensor, index: Optional[Tensor] = None,
#      20             ptr: Optional[Tensor] = None, dim_size: Optional[int] = None,
#      21             dim: int = -2) -> Tensor:
# ---> 22     return self.reduce(x, index, ptr, dim_size, dim, reduce='sum')
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/nn/aggr/base.py:176, in Aggregation.reduce(self, x, index, ptr, dim_size, dim, reduce)
#     173     return segment(x, ptr, reduce=reduce)
#     175 assert index is not None
# --> 176 return scatter(x, index, dim, dim_size, reduce)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/utils/scatter.py:70, in scatter(src, index, dim, dim_size, reduce)
#      68 if reduce == 'sum' or reduce == 'add':
#      69     index = broadcast(index, src, dim)
# ---> 70     return src.new_zeros(size).scatter_add_(dim, index, src)
#      72 if reduce == 'mean':
#      73     count = src.new_zeros(dim_size)
#
# KeyboardInterrupt:
