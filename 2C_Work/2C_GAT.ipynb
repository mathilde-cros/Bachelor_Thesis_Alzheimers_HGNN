# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pkl
import wandb

import torch
from torch_geometric.data import InMemoryDataset
from torch_geometric.utils import from_networkx

import networkx as nx
from networkx.convert_matrix import from_numpy_array

import functions as f
from functions import dict_to_array, normalize_array
import models as m
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
os.environ['WANDB_NOTEBOOK_NAME']="GAT_2Class.ipynb"

# %%
# Loading the time series
time_series_list = f.load_time_series()
time_series_df_list = f.list_of_df_of_time_series(time_series_list)

# %%
# Loading the pearson correlation matrices
corr_matrix_list = f.corr_matrix_paths()['pearson']
print(corr_matrix_list)
# Example patient
path = f'ADNI_full/corr_matrices/corr_matrix_pearson/{corr_matrix_list[0]}'
corr_matrix_patient = np.loadtxt(path, delimiter=',')
print(corr_matrix_patient)
# Out:
# ['patient_136_S_4517.csv', 'patient_130_S_4468.csv', 'patient_002_S_4654.csv', 'patient_002_S_4251.csv', 'patient_013_S_5171.csv', 'patient_130_S_2391.csv', 'patient_031_S_4947.csv', 'patient_100_S_5102.csv', 'patient_012_S_5121.csv', 'patient_053_S_5287.csv', 'patient_002_S_1261.csv', 'patient_018_S_4313.csv', 'patient_130_S_4641.csv', 'patient_012_S_4188.csv', 'patient_002_S_4521.csv', 'patient_130_S_4250.csv', 'patient_031_S_4005.csv', 'patient_130_S_5006.csv', 'patient_006_S_4363.csv', 'patient_012_S_4012.csv', 'patient_031_S_4149.csv', 'patient_031_S_4029.csv', 'patient_013_S_4917.csv', 'patient_129_S_4287.csv', 'patient_130_S_4730.csv', 'patient_129_S_0778.csv', 'patient_031_S_4203.csv', 'patient_013_S_4268.csv', 'patient_053_S_0919.csv', 'patient_002_S_4447.csv', 'patient_012_S_4987.csv', 'patient_018_S_4868.csv', 'patient_100_S_4556.csv', 'patient_100_S_5106.csv', 'patient_130_S_5175.csv', 'patient_130_S_4294.csv', 'patient_053_S_5296.csv', 'patient_031_S_4474.csv', 'patient_129_S_4396.csv', 'patient_012_S_5157.csv', 'patient_129_S_4369.csv', 'patient_013_S_2324.csv', 'patient_013_S_4580.csv', 'patient_013_S_4595.csv', 'patient_130_S_4542.csv', 'patient_006_S_4515.csv', 'patient_129_S_4220.csv', 'patient_002_S_0295.csv', 'patient_018_S_5250.csv', 'patient_012_S_5195.csv', 'patient_136_S_4993.csv', 'patient_130_S_5258.csv', 'patient_006_S_4449.csv', 'patient_002_S_0685.csv', 'patient_130_S_4352.csv', 'patient_018_S_4399.csv', 'patient_053_S_4661.csv', 'patient_018_S_4400.csv', 'patient_130_S_4971.csv', 'patient_006_S_5153.csv', 'patient_012_S_4128.csv', 'patient_002_S_4225.csv', 'patient_018_S_2138.csv', 'patient_002_S_4219.csv', 'patient_013_S_5071.csv', 'patient_031_S_4476.csv', 'patient_130_S_5059.csv', 'patient_053_S_5208.csv', 'patient_130_S_4343.csv', 'patient_136_S_4189.csv', 'patient_019_S_4680.csv', 'patient_100_S_2351.csv', 'patient_013_S_4579.csv', 'patient_136_S_0107.csv', 'patient_013_S_4791.csv', 'patient_019_S_4252.csv', 'patient_018_S_4809.csv', 'patient_019_S_4285.csv', 'patient_002_S_2043.csv', 'patient_013_S_4395.csv', 'patient_019_S_4293.csv', 'patient_100_S_4469.csv', 'patient_130_S_4817.csv', 'patient_018_S_5240.csv', 'patient_129_S_4422.csv', 'patient_006_S_4713.csv', 'patient_002_S_4746.csv', 'patient_019_S_5012.csv', 'patient_002_S_4237.csv', 'patient_018_S_4349.csv', 'patient_031_S_2018.csv', 'patient_031_S_4496.csv', 'patient_130_S_4990.csv', 'patient_130_S_4984.csv', 'patient_018_S_2133.csv', 'patient_130_S_4589.csv', 'patient_002_S_4213.csv', 'patient_136_S_4408.csv', 'patient_013_S_4985.csv', 'patient_002_S_1155.csv', 'patient_002_S_4171.csv', 'patient_031_S_2233.csv', 'patient_130_S_4417.csv', 'patient_012_S_4094.csv', 'patient_130_S_4415.csv', 'patient_006_S_4867.csv', 'patient_100_S_4512.csv', 'patient_012_S_4849.csv', 'patient_018_S_4597.csv', 'patient_031_S_4721.csv', 'patient_013_S_4616.csv', 'patient_131_S_5148.csv', 'patient_002_S_2073.csv', 'patient_031_S_2022.csv', 'patient_006_S_4679.csv', 'patient_018_S_5262.csv', 'patient_130_S_4982.csv', 'patient_136_S_4433.csv', 'patient_012_S_4643.csv', 'patient_002_S_4229.csv', 'patient_002_S_0729.csv', 'patient_012_S_5213.csv', 'patient_053_S_2396.csv', 'patient_019_S_5019.csv', 'patient_013_S_1186.csv', 'patient_130_S_4997.csv', 'patient_031_S_4042.csv', 'patient_010_S_4345.csv', 'patient_006_S_4485.csv', 'patient_041_S_5026.csv', 'patient_130_S_4405.csv', 'patient_053_S_5202.csv', 'patient_130_S_4605.csv', 'patient_129_S_4371.csv', 'patient_019_S_4477.csv', 'patient_053_S_2357.csv', 'patient_013_S_5137.csv', 'patient_002_S_4799.csv', 'patient_002_S_5256.csv', 'patient_053_S_4813.csv', 'patient_012_S_4545.csv', 'patient_002_S_0413.csv', 'patient_031_S_4032.csv', 'patient_031_S_4218.csv', 'patient_002_S_4264.csv', 'patient_002_S_4270.csv', 'patient_019_S_5242.csv', 'patient_006_S_0731.csv', 'patient_019_S_4835.csv', 'patient_130_S_4925.csv', 'patient_053_S_4557.csv', 'patient_130_S_2373.csv', 'patient_002_S_5230.csv', 'patient_006_S_4153.c ...
# [[ 1.          0.62126391  0.40501965 ... -0.07884583  0.07740484
#   -0.36456412]
#  [ 0.62126391  1.         -0.0033939  ...  0.02684759  0.0412815
#   -0.1746839 ]
#  [ 0.40501965 -0.0033939   1.         ... -0.17088309 -0.15494682
#   -0.09877457]
#  ...
#  [-0.07884583  0.02684759 -0.17088309 ...  1.          0.39632277
#    0.00382471]
#  [ 0.07740484  0.0412815  -0.15494682 ...  0.39632277  1.
#    0.35172939]
#  [-0.36456412 -0.1746839  -0.09877457 ...  0.00382471  0.35172939
#    1.        ]]

# %%
# Loading the diagnostic labels
diagnostic_label_all = np.loadtxt('ADNI_full/diagnostic_label.csv', dtype=str, delimiter=',')

# %%
def filter_group(group):
    df = pd.read_csv('ADNI_FULL/patient_info.csv')
    labels = df['Research Group']
    label_idx_list = [i for i in range(len(labels)) if labels[i] == group]
    return label_idx_list

# %%
#binary classification
cn = filter_group('CN')
ad = filter_group('AD')
bin_idx = sorted(cn + ad)
corr_matrices = [corr_matrix_list[i] for i in bin_idx]
diagnostic_label = [diagnostic_label_all[i] for i in bin_idx]
for i in range(len(diagnostic_label)):
    if diagnostic_label[i] == 'CN':
        diagnostic_label[i] = 0
    elif diagnostic_label[i] == 'AD':
        diagnostic_label[i] = 1
    else:
        print('Error: incorrect label')

# %%
assert len(diagnostic_label) == len(corr_matrices)

# %%
# Defining a class to preprocess raw data into a format suitable for training Graph Neural Networks (GNNs).
## With the possibility of assigning weight to edges, adding the age feature, sex feature, and matrixe profiling.

class Raw_to_Graph_2Class(InMemoryDataset):
    def __init__(self, root, threshold, method, weight=False, age=False, sex=False, matrixprofile=False, transform=None, pre_transform=None):
        self.threshold = threshold
        self.method = method
        self.weight = weight
        self.age = age
        self.sex = sex
        self.matrixprofile = matrixprofile
        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def processed_file_names(self):
        return ['data.pt']

    # This function is used to process the raw data into a format suitable for GNNs, by constructing graphs out of the connectivity matrices.
    def process(self):
        graphs=[]
        for patient_idx, patient_matrix in enumerate(corr_matrices):
            path = f'ADNI_full/corr_matrices/corr_matrix_{self.method}/{patient_matrix}'
            corr_matrix = np.loadtxt(path, delimiter=',')
            # Here ROIs stands for Regions of Interest
            nbr_ROIs = corr_matrix.shape[0]
            edge_matrix = np.zeros((nbr_ROIs,nbr_ROIs))
            for j in range(nbr_ROIs):
                for k in range(nbr_ROIs):
                    # Here we are using the absolute value of each element of the correlation matrix, as the corr coeff is in the range [-1,1].
                    if np.abs(corr_matrix[j,k]) < self.threshold:
                        edge_matrix[j,k] = 0
                    else:
                        if self.weight:
                            # Here we assign the absolute value of the correlation coefficient as the edge weight.
                            edge_matrix[j,k] = corr_matrix[j,k]
                        else:
                            # Here we assign 1 as the edge weight, i.e. regardless of the the absolute value of the correlation coefficient.
                            edge_matrix[j,k] = 1

            # Create a NetworkX graph from the edge matrix
            NetworkX_graph = from_numpy_array(edge_matrix)

            # Compute the degree, betweenness centrality, clustering coefficient, local efficiency for each node of the graph and the global efficiency of the graph
            degree_dict = dict(NetworkX_graph.degree())
            between_central_dict = nx.betweenness_centrality(NetworkX_graph)
            cluster_coeff_dict = nx.clustering(NetworkX_graph)
            global_eff = nx.global_efficiency(NetworkX_graph)
            local_eff_dict = {}
            for node in NetworkX_graph.nodes():
                subgraph_neighb = NetworkX_graph.subgraph(NetworkX_graph.neighbors(node))
                if subgraph_neighb.number_of_nodes() > 1:
                    efficiency = nx.global_efficiency(subgraph_neighb)
                else:
                    efficiency = 0.0
                local_eff_dict[node] = efficiency

            # Convert the degree, betweenness centrality, local efficiency, clustering coefficient and ratio of local to global efficiency dictionaries to NumPy arrays then normalize them
            degree_array = dict_to_array(degree_dict)
            degree_array_norm = normalize_array(degree_array)

            between_central_array = dict_to_array(between_central_dict)
            between_central_array_norm = normalize_array(between_central_array)

            local_efficiency_array = dict_to_array(local_eff_dict)
            local_eff_array_norm = normalize_array(local_efficiency_array)

            ratio_local_global_array = dict_to_array(local_eff_dict) / global_eff
            ratio_local_global_array_norm = normalize_array(ratio_local_global_array)

            cluster_coeff_array = dict_to_array(cluster_coeff_dict)
            cluster_coeff_array_norm = normalize_array(cluster_coeff_array)

            # Initializing an array for the graph features
            x_array = np.stack([degree_array_norm, between_central_array_norm, local_eff_array_norm, cluster_coeff_array_norm, ratio_local_global_array_norm], axis=-1)
            x_array = x_array.astype(np.float32)
            
            if self.matrixprofile:
                path = f'ADNI_full/matrix_profiles/matrix_profile_{self.method}/{patient_matrix}'
                with open(path, "rb") as fl:
                  patient_dict = pkl.load(fl)
                # combine dimensions
                features = np.array(patient_dict['mp']).reshape(len(patient_dict['mp']),-1)
                features = features.astype(np.float32)
                x_array = np.concatenate((x_array, features), axis=-1)

            # Concatenate the degree, participation coefficient, betweenness centrality, local efficiency, and ratio of local to global efficiency arrays to form a single feature vector
            x = torch.tensor(x_array, dtype=torch.float)

            # Create a Pytorch Geometric Data object from the NetworkX
            graph_data = from_networkx(NetworkX_graph)
            ## The feature matrix of the graph is the degree, betweenness centrality, local efficiency, clustering coefficient and ratio of local to global efficiency of each node
            graph_data.x = x
            ## The target/output variable that we want to predict is the diagnostic label of the patient
            graph_data.y = float(diagnostic_label[patient_idx])
            graphs.append(graph_data)

        data, slices = self.collate(graphs)
        torch.save((data, slices), self.processed_paths[0])

# %%
# Doing some parameter gridsearch to find the best hyperparameters
from sklearn.model_selection import ParameterGrid

# Building the graphs
threshold = 0.5
age = False
sex = False
matrixprofile = True
weight = True
if matrixprofile:
    in_channels = 461 + int(age) + int(sex)
else:
    in_channels = 5 + int(age) + int(sex)
method = 'pearson'

root = f'Raw_to_graph_2Class/ADNI_T_{threshold}_M_{method}_W{weight}_A{age}_S{sex}_MP{matrixprofile}'
dataset = Raw_to_Graph_2Class(root=root, threshold=threshold, method=method, weight=weight, sex=sex, age=age, matrixprofile=matrixprofile)
f.dataset_features_and_stats(dataset, diagnostic_label)

# Creating the train, validation and test sets
train_loader, valid_loader, test_loader, nbr_classes = f.create_train_test_valid(dataset)

# param_grid = {
#     'learning_rate': [0.001, 0.0001],
#     'hidden_channels': [128, 64],
#     'num_layers': [3, 2, 1],
#     'dropout_rate': [0.2, 0.1, 0.0],
#     'weight_decay': [0.001, 0.0001],
#     'heads': [4, 3]
# }
param_grid = {
    'learning_rate': [0.0001, 0.001],
    'hidden_channels': [64, 128],
    'num_layers': [1, 2, 3],
    'dropout_rate': [0.0, 0.1, 0.2],
    'weight_decay': [0.0001, 0.001],
    'heads': [3, 4]
}

# Create combinations of hyperparameters
param_combinations = ParameterGrid(param_grid)
n_epochs = 500
# Train using each combination
for params in param_combinations:
    if matrixprofile:
        filename = f'2Class_Models/GAT_Models_MP/threshold_{threshold}/lr{params["learning_rate"]}_hc{params["hidden_channels"]}_nl{params["num_layers"]}_d{params["dropout_rate"]}_epochs{n_epochs}_heads{params["heads"]}_wdecay{params["weight_decay"]}_w{weight}.png'
    else:
        filename = f'2Class_Models/GAT_Models/threshold_{threshold}/lr{params["learning_rate"]}_hc{params["hidden_channels"]}_nl{params["num_layers"]}_d{params["dropout_rate"]}_epochs{n_epochs}_heads{params["heads"]}_wdecay{params["weight_decay"]}_w{weight}.png'
    if os.path.exists(filename):
        pass
    else:
        parameters = [params['learning_rate'], params['hidden_channels'], params['num_layers'], params['dropout_rate'], params['heads']]
        model = m.GAT(in_channels=in_channels, hidden_channels=parameters[1], out_channels=nbr_classes, num_layers=parameters[2], dropout=parameters[3], heads=parameters[4], nbr_classes=nbr_classes)
        criterion = torch.nn.CrossEntropyLoss()
        if 'weight_decay' not in params.keys():
            w_decay = 0
        else:
            w_decay = params['weight_decay']
        optimizer = torch.optim.Adam(model.parameters(), lr=parameters[0], weight_decay=w_decay)
        train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = m.train_GAT(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing=True, n_epochs=800)
# Out:
# Dataset: Raw_to_Graph_2Class(78):
# ====================
# Number of graphs: 78
# Weighted: True
# Threshold: 0.5
# Correlation Method: pearson
# Number of features: 461
# Number of classes: 2
#
# Data(edge_index=[2, 1116], weight=[1116], x=[116, 461], y=[1], num_nodes=116)
# =============================================================
# Number of nodes: 116
# Number of edges: 1116
# Average node degree: 9.62
# Has isolated nodes: True
# Has self-loops: True
# Is undirected: True
# Number of training graphs: 54
# Number of validation graphs: 8
# Number of test graphs: 16
# Number of classes: 2
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/data/in_memory_dataset.py:284: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find GAT_2Class.ipynb.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# wandb: Currently logged in as: mathilde-cros (alzheimers-cl). Use `wandb login --relogin` to force relogin
# /Users/mathilde/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# wandb version 0.16.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/Users/mathilde/Documents/Bachelor-Thesis-Alzheimers-HGNN/wandb/run-20240313_040430-3j85zez6</code>
# Syncing run <strong><a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/3j85zez6' target="_blank">stilted-pond-4827</a></strong> to <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN</a>
#  View run at <a href='https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/3j85zez6' target="_blank">https://wandb.ai/alzheimers-cl/Alzheimers_GNN/runs/3j85zez6</a>
# Epoch 1/800
# Train Loss: 9.8391, Validation Loss: 7.4799
# Train Accuracy: 0.6615, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 2/800
# Train Loss: 2.8987, Validation Loss: 1.6152
# Train Accuracy: 0.6354, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 3/800
# Train Loss: 2.6385, Validation Loss: 1.4080
# Train Accuracy: 0.3906, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 4/800
# Train Loss: 1.0491, Validation Loss: 1.8221
# Train Accuracy: 0.5365, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 5/800
# Train Loss: 1.7191, Validation Loss: 1.7062
# Train Accuracy: 0.6094, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 6/800
# Train Loss: 0.8978, Validation Loss: 0.8753
# Train Accuracy: 0.6458, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 7/800
# Train Loss: 1.1056, Validation Loss: 0.8763
# Train Accuracy: 0.4219, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 8/800
# Train Loss: 0.7428, Validation Loss: 1.0544
# Train Accuracy: 0.5729, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.5000
# Epoch 9/800
# Train Loss: 0.8324, Validation Loss: 0.8757
# Train Accuracy: 0.6354, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 10/800
# Train Loss: 0.5905, Validation Loss: 0.7766
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 11/800
# Train Loss: 0.7610, Validation Loss: 0.7469
# Train Accuracy: 0.5938, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 12/800
# Train Loss: 0.7027, Validation Loss: 0.9108
# Train Accuracy: 0.5521, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 13/800
# Train Loss: 0.6056, Validation Loss: 0.7289
# Train Accuracy: 0.6510, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 14/800
# Train Loss: 0.5845, Validation Loss: 0.7396
# Train Accuracy: 0.7552, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 15/800
# Train Loss: 0.5627, Validation Loss: 0.7863
# Train Accuracy: 0.6823, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 16/800
# Train Loss: 0.5279, Validation Loss: 0.7546
# Train Accuracy: 0.7083, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 17/800
# Train Loss: 0.5638, Validation Loss: 0.7438
# Train Accuracy: 0.6875, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 18/800
# Train Loss: 0.5397, Validation Loss: 0.7436
# Train Accuracy: 0.7188, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 19/800
# Train Loss: 0.5105, Validation Loss: 0.7817
# Train Accuracy: 0.7292, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 20/800
# Train Loss: 0.4841, Validation Loss: 0.7258
# Train Accuracy: 0.7083, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 21/800
# Train Loss: 0.5115, Validation Loss: 0.7406
# Train Accuracy: 0.7604, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 22/800
# Train Loss: 0.4706, Validation Loss: 0.7810
# Train Accuracy: 0.7240, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 23/800
# Train Loss: 0.4609, Validation Loss: 0.7164
# Train Accuracy: 0.7396, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 24/800
# Train Loss: 0.4751, Validation Loss: 0.7263
# Train Accuracy: 0.7604, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 25/800
# Train Loss: 0.4557, Validation Loss: 0.7204
# Train Accuracy: 0.7812, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 26/800
# Train Loss: 0.4442, Validation Loss: 0.7246
# Train Accuracy: 0.8490, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 27/800
# Train Loss: 0.3860, Validation Loss: 0.8474
# Train Accuracy: 0.8125, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 28/800
# Train Loss: 0.4219, Validation Loss: 0.7254
# Train Accuracy: 0.7083, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 29/800
# Train Loss: 0.3698, Validation Loss: 0.7214
# Train Accuracy: 0.8906, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 30/800
# Train Loss: 0.3768, Validation Loss: 0.7846
# Train Accuracy: 0.8906, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 31/800
# Train Loss: 0.4195, Validation Loss: 0.7454
# Train Accuracy: 0.7448, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 32/800
# Train Loss: 0.3788, Validation Loss: 0.7174
# Train Accuracy: 0.8750, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 33/800
# Train Loss: 0.4007, Validation Loss: 0.7660
# Train Accuracy: 0.8750, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 34/800
# Train Loss: 0.3663, Validation Loss: 0.7325
# Train Accuracy: 0.8281, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 35/800
# Train Loss: 0.3341, Validation Loss: 0.6930
# Train Accuracy: 0.9219, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 36/800
# Train Loss: 0.3599, Validation Loss: 0.7222
# Train Accuracy: 0.8802, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 37/800
# Train Loss: 0.3427, Validation Loss: 0.7233
# Train Accuracy: 0.9219, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 38/800
# Train Loss: 0.3546, Validation Loss: 0.6858
# Train Accuracy: 0.9271, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 39/800
# Train Loss: 0.3228, Validation Loss: 0.7502
# Train Accuracy: 0.9688, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 40/800
# Train Loss: 0.3403, Validation Loss: 0.6973
# Train Accuracy: 0.8750, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 41/800
# Train Loss: 0.3144, Validation Loss: 0.6752
# Train Accuracy: 0.9531, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 42/800
# Train Loss: 0.3261, Validation Loss: 0.7550
# Train Accuracy: 0.9271, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 43/800
# Train Loss: 0.3409, Validation Loss: 0.7273
# Train Accuracy: 0.8906, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 44/800
# Train Loss: 0.3063, Validation Loss: 0.6676
# Train Accuracy: 0.9115, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.6250
# Epoch 45/800
# Train Loss: 0.3062, Validation Loss: 0.7073
# Train Accuracy: 0.9271, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.6250
# Epoch 46/800
# Train Loss: 0.2723, Validation Loss: 0.6590
# Train Accuracy: 0.9688, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 47/800
# Train Loss: 0.3076, Validation Loss: 0.7374
# Train Accuracy: 0.9688, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 48/800
# Train Loss: 0.3509, Validation Loss: 0.7026
# Train Accuracy: 0.7500, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 49/800
# Train Loss: 0.2731, Validation Loss: 0.6771
# Train Accuracy: 0.9375, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 50/800
# Train Loss: 0.3036, Validation Loss: 0.7715
# Train Accuracy: 0.9271, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 51/800
# Train Loss: 0.2633, Validation Loss: 0.6465
# Train Accuracy: 0.9062, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 52/800
# Train Loss: 0.2876, Validation Loss: 0.6612
# Train Accuracy: 0.9531, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 53/800
# Train Loss: 0.2661, Validation Loss: 0.7418
# Train Accuracy: 0.9583, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 54/800
# Train Loss: 0.2691, Validation Loss: 0.6390
# Train Accuracy: 0.9844, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 55/800
# Train Loss: 0.2693, Validation Loss: 0.6951
# Train Accuracy: 0.9583, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 56/800
# Train Loss: 0.2364, Validation Loss: 0.6306
# Train Accuracy: 0.9531, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 57/800
# Train Loss: 0.2279, Validation Loss: 0.7001
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 58/800
# Train Loss: 0.2258, Validation Loss: 0.6225
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 59/800
# Train Loss: 0.2620, Validation Loss: 0.6259
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 60/800
# Train Loss: 0.2715, Validation Loss: 0.6637
# Train Accuracy: 0.9583, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 61/800
# Train Loss: 0.3184, Validation Loss: 0.6251
# Train Accuracy: 0.8698, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 62/800
# Train Loss: 0.3713, Validation Loss: 0.6222
# Train Accuracy: 0.8073, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 63/800
# Train Loss: 0.2554, Validation Loss: 0.9376
# Train Accuracy: 0.8594, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 64/800
# Train Loss: 0.2658, Validation Loss: 0.6594
# Train Accuracy: 0.9375, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 65/800
# Train Loss: 0.2394, Validation Loss: 0.7896
# Train Accuracy: 0.9531, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 66/800
# Train Loss: 0.2652, Validation Loss: 0.6436
# Train Accuracy: 0.9219, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 67/800
# Train Loss: 0.2744, Validation Loss: 0.5984
# Train Accuracy: 0.8854, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 68/800
# Train Loss: 0.3049, Validation Loss: 0.7797
# Train Accuracy: 0.8021, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 69/800
# Train Loss: 0.2984, Validation Loss: 0.6317
# Train Accuracy: 0.9688, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 70/800
# Train Loss: 0.2993, Validation Loss: 0.7905
# Train Accuracy: 0.8854, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 71/800
# Train Loss: 0.1988, Validation Loss: 0.6256
# Train Accuracy: 0.9844, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 72/800
# Train Loss: 0.2185, Validation Loss: 0.7774
# Train Accuracy: 0.9844, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 73/800
# Train Loss: 0.2176, Validation Loss: 0.6078
# Train Accuracy: 0.9531, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 74/800
# Train Loss: 0.2466, Validation Loss: 0.6153
# Train Accuracy: 0.9583, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 75/800
# Train Loss: 0.2062, Validation Loss: 0.8346
# Train Accuracy: 0.9688, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 76/800
# Train Loss: 0.2089, Validation Loss: 0.5983
# Train Accuracy: 0.9844, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 77/800
# Train Loss: 0.1813, Validation Loss: 0.7043
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 78/800
# Train Loss: 0.1776, Validation Loss: 0.6292
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 79/800
# Train Loss: 0.1498, Validation Loss: 0.6528
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 80/800
# Train Loss: 0.1599, Validation Loss: 0.6136
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 81/800
# Train Loss: 0.1639, Validation Loss: 0.6082
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 82/800
# Train Loss: 0.1487, Validation Loss: 0.6768
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 83/800
# Train Loss: 0.1719, Validation Loss: 0.6378
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 84/800
# Train Loss: 0.1502, Validation Loss: 0.5937
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 85/800
# Train Loss: 0.1709, Validation Loss: 0.7260
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 86/800
# Train Loss: 0.1593, Validation Loss: 0.6742
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 87/800
# Train Loss: 0.1343, Validation Loss: 0.5903
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 88/800
# Train Loss: 0.1502, Validation Loss: 0.6443
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 89/800
# Train Loss: 0.1315, Validation Loss: 0.6286
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 90/800
# Train Loss: 0.1480, Validation Loss: 0.6459
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 91/800
# Train Loss: 0.1413, Validation Loss: 0.6611
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 92/800
# Train Loss: 0.1308, Validation Loss: 0.6038
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 93/800
# Train Loss: 0.1364, Validation Loss: 0.6663
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 94/800
# Train Loss: 0.1361, Validation Loss: 0.6238
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 95/800
# Train Loss: 0.1479, Validation Loss: 0.6354
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 96/800
# Train Loss: 0.1512, Validation Loss: 0.6909
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 97/800
# Train Loss: 0.1261, Validation Loss: 0.5862
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 98/800
# Train Loss: 0.1314, Validation Loss: 0.6766
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 99/800
# Train Loss: 0.1447, Validation Loss: 0.5928
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 100/800
# Train Loss: 0.1716, Validation Loss: 0.6211
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 101/800
# Train Loss: 0.2065, Validation Loss: 0.6924
# Train Accuracy: 0.9271, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 102/800
# Train Loss: 0.1701, Validation Loss: 0.6032
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 103/800
# Train Loss: 0.1302, Validation Loss: 0.9040
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 104/800
# Train Loss: 0.1462, Validation Loss: 0.5791
# Train Accuracy: 0.9844, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 105/800
# Train Loss: 0.1473, Validation Loss: 0.6229
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 106/800
# Train Loss: 0.1196, Validation Loss: 0.7103
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 107/800
# Train Loss: 0.1066, Validation Loss: 0.5813
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 108/800
# Train Loss: 0.1171, Validation Loss: 0.6654
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 109/800
# Train Loss: 0.1162, Validation Loss: 0.6170
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 110/800
# Train Loss: 0.0998, Validation Loss: 0.6308
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 111/800
# Train Loss: 0.0989, Validation Loss: 0.6473
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 112/800
# Train Loss: 0.1011, Validation Loss: 0.6156
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 113/800
# Train Loss: 0.0998, Validation Loss: 0.6271
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 114/800
# Train Loss: 0.0981, Validation Loss: 0.6056
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 115/800
# Train Loss: 0.0921, Validation Loss: 0.6103
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 116/800
# Train Loss: 0.0932, Validation Loss: 0.6420
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 117/800
# Train Loss: 0.0967, Validation Loss: 0.5919
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 118/800
# Train Loss: 0.0995, Validation Loss: 0.6133
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 119/800
# Train Loss: 0.1046, Validation Loss: 0.6837
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 120/800
# Train Loss: 0.1066, Validation Loss: 0.5919
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 121/800
# Train Loss: 0.0889, Validation Loss: 0.7159
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 122/800
# Train Loss: 0.0885, Validation Loss: 0.6061
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 123/800
# Train Loss: 0.0863, Validation Loss: 0.6373
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 124/800
# Train Loss: 0.0840, Validation Loss: 0.6576
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 125/800
# Train Loss: 0.0853, Validation Loss: 0.5989
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 126/800
# Train Loss: 0.0862, Validation Loss: 0.6279
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 127/800
# Train Loss: 0.0784, Validation Loss: 0.6763
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 128/800
# Train Loss: 0.0866, Validation Loss: 0.6013
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 129/800
# Train Loss: 0.0911, Validation Loss: 0.6069
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 130/800
# Train Loss: 0.0849, Validation Loss: 0.6770
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 131/800
# Train Loss: 0.0802, Validation Loss: 0.5916
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 132/800
# Train Loss: 0.0768, Validation Loss: 0.6533
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 133/800
# Train Loss: 0.0859, Validation Loss: 0.6245
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 134/800
# Train Loss: 0.0759, Validation Loss: 0.6042
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 135/800
# Train Loss: 0.0779, Validation Loss: 0.6899
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 136/800
# Train Loss: 0.0742, Validation Loss: 0.6274
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 137/800
# Train Loss: 0.0702, Validation Loss: 0.6029
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 138/800
# Train Loss: 0.0696, Validation Loss: 0.6279
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 139/800
# Train Loss: 0.0783, Validation Loss: 0.6080
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 140/800
# Train Loss: 0.0724, Validation Loss: 0.6083
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 141/800
# Train Loss: 0.0718, Validation Loss: 0.6838
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 142/800
# Train Loss: 0.0739, Validation Loss: 0.6018
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 143/800
# Train Loss: 0.0850, Validation Loss: 0.6573
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 144/800
# Train Loss: 0.0760, Validation Loss: 0.7423
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 145/800
# Train Loss: 0.0716, Validation Loss: 0.5912
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 146/800
# Train Loss: 0.0688, Validation Loss: 0.7105
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 147/800
# Train Loss: 0.0799, Validation Loss: 0.6516
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 148/800
# Train Loss: 0.0775, Validation Loss: 0.5935
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 149/800
# Train Loss: 0.0710, Validation Loss: 0.7759
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 150/800
# Train Loss: 0.0788, Validation Loss: 0.6073
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 151/800
# Train Loss: 0.0630, Validation Loss: 0.6634
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 152/800
# Train Loss: 0.0659, Validation Loss: 0.6305
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 153/800
# Train Loss: 0.0613, Validation Loss: 0.6075
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 154/800
# Train Loss: 0.0630, Validation Loss: 0.6446
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 155/800
# Train Loss: 0.0601, Validation Loss: 0.6826
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 156/800
# Train Loss: 0.0596, Validation Loss: 0.6175
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 157/800
# Train Loss: 0.0609, Validation Loss: 0.6198
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 158/800
# Train Loss: 0.0589, Validation Loss: 0.6821
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 159/800
# Train Loss: 0.0590, Validation Loss: 0.6903
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 160/800
# Train Loss: 0.0551, Validation Loss: 0.6216
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 161/800
# Train Loss: 0.0574, Validation Loss: 0.6306
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 162/800
# Train Loss: 0.0561, Validation Loss: 0.6040
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 163/800
# Train Loss: 0.0531, Validation Loss: 0.6056
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 164/800
# Train Loss: 0.0675, Validation Loss: 0.6644
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 165/800
# Train Loss: 0.0607, Validation Loss: 0.5797
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 166/800
# Train Loss: 0.0509, Validation Loss: 0.7879
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 167/800
# Train Loss: 0.0617, Validation Loss: 0.6330
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 168/800
# Train Loss: 0.0501, Validation Loss: 0.5985
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 169/800
# Train Loss: 0.0521, Validation Loss: 0.6576
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 170/800
# Train Loss: 0.0489, Validation Loss: 0.6195
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 171/800
# Train Loss: 0.0533, Validation Loss: 0.6268
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 172/800
# Train Loss: 0.0494, Validation Loss: 0.5795
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 173/800
# Train Loss: 0.0564, Validation Loss: 0.6260
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 174/800
# Train Loss: 0.0473, Validation Loss: 0.6787
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 175/800
# Train Loss: 0.0462, Validation Loss: 0.6242
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 176/800
# Train Loss: 0.0464, Validation Loss: 0.6259
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 177/800
# Train Loss: 0.0474, Validation Loss: 0.6267
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 178/800
# Train Loss: 0.0456, Validation Loss: 0.6422
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 179/800
# Train Loss: 0.0463, Validation Loss: 0.6060
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 180/800
# Train Loss: 0.0451, Validation Loss: 0.6756
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 181/800
# Train Loss: 0.0484, Validation Loss: 0.6607
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 182/800
# Train Loss: 0.0390, Validation Loss: 0.5672
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 183/800
# Train Loss: 0.0468, Validation Loss: 0.7028
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 184/800
# Train Loss: 0.0445, Validation Loss: 0.6844
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 185/800
# Train Loss: 0.0411, Validation Loss: 0.5926
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 186/800
# Train Loss: 0.0400, Validation Loss: 0.6647
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 187/800
# Train Loss: 0.0424, Validation Loss: 0.6685
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 188/800
# Train Loss: 0.0466, Validation Loss: 0.6291
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 189/800
# Train Loss: 0.0439, Validation Loss: 0.7086
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 190/800
# Train Loss: 0.0417, Validation Loss: 0.5707
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 191/800
# Train Loss: 0.0397, Validation Loss: 0.6772
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 192/800
# Train Loss: 0.0394, Validation Loss: 0.6431
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 193/800
# Train Loss: 0.0414, Validation Loss: 0.5830
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 194/800
# Train Loss: 0.0447, Validation Loss: 0.6002
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 195/800
# Train Loss: 0.0414, Validation Loss: 0.7254
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 196/800
# Train Loss: 0.0398, Validation Loss: 0.5662
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 197/800
# Train Loss: 0.0394, Validation Loss: 0.6960
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 198/800
# Train Loss: 0.0400, Validation Loss: 0.6282
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 199/800
# Train Loss: 0.0391, Validation Loss: 0.5872
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 200/800
# Train Loss: 0.0344, Validation Loss: 0.7334
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 201/800
# Train Loss: 0.0385, Validation Loss: 0.5988
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 202/800
# Train Loss: 0.0379, Validation Loss: 0.5992
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 203/800
# Train Loss: 0.0372, Validation Loss: 0.6965
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 204/800
# Train Loss: 0.0375, Validation Loss: 0.5866
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 205/800
# Train Loss: 0.0357, Validation Loss: 0.6051
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 206/800
# Train Loss: 0.0331, Validation Loss: 0.6727
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 207/800
# Train Loss: 0.0355, Validation Loss: 0.6296
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 208/800
# Train Loss: 0.0334, Validation Loss: 0.6022
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 209/800
# Train Loss: 0.0331, Validation Loss: 0.7096
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 210/800
# Train Loss: 0.0346, Validation Loss: 0.5899
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 211/800
# Train Loss: 0.0317, Validation Loss: 0.6138
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 212/800
# Train Loss: 0.0375, Validation Loss: 0.6562
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 213/800
# Train Loss: 0.0354, Validation Loss: 0.5651
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 214/800
# Train Loss: 0.0384, Validation Loss: 0.7038
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 215/800
# Train Loss: 0.0309, Validation Loss: 0.5725
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 216/800
# Train Loss: 0.0311, Validation Loss: 0.6653
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 217/800
# Train Loss: 0.0299, Validation Loss: 0.6340
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 218/800
# Train Loss: 0.0314, Validation Loss: 0.6094
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 219/800
# Train Loss: 0.0278, Validation Loss: 0.6523
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 220/800
# Train Loss: 0.0292, Validation Loss: 0.6396
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 221/800
# Train Loss: 0.0312, Validation Loss: 0.6029
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 222/800
# Train Loss: 0.0298, Validation Loss: 0.7163
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 223/800
# Train Loss: 0.0297, Validation Loss: 0.5914
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 224/800
# Train Loss: 0.0268, Validation Loss: 0.6899
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 225/800
# Train Loss: 0.0304, Validation Loss: 0.6520
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 226/800
# Train Loss: 0.0285, Validation Loss: 0.6097
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 227/800
# Train Loss: 0.0290, Validation Loss: 0.6867
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 228/800
# Train Loss: 0.0295, Validation Loss: 0.5809
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 229/800
# Train Loss: 0.0283, Validation Loss: 0.6906
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 230/800
# Train Loss: 0.0272, Validation Loss: 0.5910
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 231/800
# Train Loss: 0.0268, Validation Loss: 0.5802
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 232/800
# Train Loss: 0.0254, Validation Loss: 0.6995
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 233/800
# Train Loss: 0.0278, Validation Loss: 0.6250
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 234/800
# Train Loss: 0.0244, Validation Loss: 0.6008
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 235/800
# Train Loss: 0.0243, Validation Loss: 0.7067
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 236/800
# Train Loss: 0.0312, Validation Loss: 0.6409
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 237/800
# Train Loss: 0.0304, Validation Loss: 0.5540
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 238/800
# Train Loss: 0.0273, Validation Loss: 0.8103
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 239/800
# Train Loss: 0.0265, Validation Loss: 0.5878
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 240/800
# Train Loss: 0.0241, Validation Loss: 0.6080
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 241/800
# Train Loss: 0.0240, Validation Loss: 0.6612
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 242/800
# Train Loss: 0.0222, Validation Loss: 0.6258
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 243/800
# Train Loss: 0.0219, Validation Loss: 0.6723
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 244/800
# Train Loss: 0.0217, Validation Loss: 0.6558
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 245/800
# Train Loss: 0.0218, Validation Loss: 0.6355
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 246/800
# Train Loss: 0.0221, Validation Loss: 0.6429
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 247/800
# Train Loss: 0.0226, Validation Loss: 0.5980
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 248/800
# Train Loss: 0.0197, Validation Loss: 0.7503
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 249/800
# Train Loss: 0.0277, Validation Loss: 0.6508
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 250/800
# Train Loss: 0.0264, Validation Loss: 0.5629
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 251/800
# Train Loss: 0.0205, Validation Loss: 0.8084
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 252/800
# Train Loss: 0.0245, Validation Loss: 0.6116
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 253/800
# Train Loss: 0.0225, Validation Loss: 0.5729
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 254/800
# Train Loss: 0.0240, Validation Loss: 0.7228
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 255/800
# Train Loss: 0.0202, Validation Loss: 0.5897
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 256/800
# Train Loss: 0.0223, Validation Loss: 0.6121
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 257/800
# Train Loss: 0.0198, Validation Loss: 0.7109
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 258/800
# Train Loss: 0.0191, Validation Loss: 0.6548
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 259/800
# Train Loss: 0.0196, Validation Loss: 0.6050
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 260/800
# Train Loss: 0.0198, Validation Loss: 0.6173
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 261/800
# Train Loss: 0.0188, Validation Loss: 0.7119
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 262/800
# Train Loss: 0.0190, Validation Loss: 0.6340
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 263/800
# Train Loss: 0.0189, Validation Loss: 0.6210
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 264/800
# Train Loss: 0.0198, Validation Loss: 0.7014
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 265/800
# Train Loss: 0.0184, Validation Loss: 0.5882
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 266/800
# Train Loss: 0.0186, Validation Loss: 0.6673
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 267/800
# Train Loss: 0.0172, Validation Loss: 0.6741
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 268/800
# Train Loss: 0.0175, Validation Loss: 0.6358
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 269/800
# Train Loss: 0.0198, Validation Loss: 0.6608
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 270/800
# Train Loss: 0.0201, Validation Loss: 0.5802
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 271/800
# Train Loss: 0.0192, Validation Loss: 0.7424
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 272/800
# Train Loss: 0.0175, Validation Loss: 0.6158
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 273/800
# Train Loss: 0.0167, Validation Loss: 0.6465
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 274/800
# Train Loss: 0.0174, Validation Loss: 0.6584
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 275/800
# Train Loss: 0.0158, Validation Loss: 0.5972
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 276/800
# Train Loss: 0.0164, Validation Loss: 0.6984
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 277/800
# Train Loss: 0.0169, Validation Loss: 0.6437
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 278/800
# Train Loss: 0.0158, Validation Loss: 0.5854
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 279/800
# Train Loss: 0.0175, Validation Loss: 0.7278
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 280/800
# Train Loss: 0.0172, Validation Loss: 0.6581
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 281/800
# Train Loss: 0.0162, Validation Loss: 0.5980
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 282/800
# Train Loss: 0.0174, Validation Loss: 0.6969
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 283/800
# Train Loss: 0.0153, Validation Loss: 0.6208
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 284/800
# Train Loss: 0.0154, Validation Loss: 0.6419
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 285/800
# Train Loss: 0.0155, Validation Loss: 0.7378
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 286/800
# Train Loss: 0.0147, Validation Loss: 0.5960
# Train Accuracy: 1.0000, Validation Accuracy: 0.8750
# Max Validation Accuracy: 0.8750
# Epoch 287/800
# Train Loss: 0.0159, Validation Loss: 0.6501
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 288/800
# Train Loss: 0.0134, Validation Loss: 0.7709
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 289/800
# Train Loss: 0.0145, Validation Loss: 0.6253
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 290/800
# Train Loss: 0.0145, Validation Loss: 0.6066
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 291/800
# Train Loss: 0.0148, Validation Loss: 0.7030
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 292/800
# Train Loss: 0.0139, Validation Loss: 0.6683
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 293/800
# Train Loss: 0.0130, Validation Loss: 0.6673
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 294/800
# Train Loss: 0.0132, Validation Loss: 0.6954
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 295/800
# Train Loss: 0.0124, Validation Loss: 0.6498
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 296/800
# Train Loss: 0.0125, Validation Loss: 0.6549
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 297/800
# Train Loss: 0.0140, Validation Loss: 0.6478
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 298/800
# Train Loss: 0.0126, Validation Loss: 0.6411
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 299/800
# Train Loss: 0.0134, Validation Loss: 0.6951
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 300/800
# Train Loss: 0.0120, Validation Loss: 0.6673
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 301/800
# Train Loss: 0.0117, Validation Loss: 0.6797
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 302/800
# Train Loss: 0.0120, Validation Loss: 0.6636
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 303/800
# Train Loss: 0.0122, Validation Loss: 0.6311
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 304/800
# Train Loss: 0.0123, Validation Loss: 0.7003
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 305/800
# Train Loss: 0.0123, Validation Loss: 0.7023
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 306/800
# Train Loss: 0.0128, Validation Loss: 0.6223
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 307/800
# Train Loss: 0.0115, Validation Loss: 0.6882
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 308/800
# Train Loss: 0.0118, Validation Loss: 0.6843
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 309/800
# Train Loss: 0.0127, Validation Loss: 0.7108
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 310/800
# Train Loss: 0.0131, Validation Loss: 0.6365
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 311/800
# Train Loss: 0.0136, Validation Loss: 0.7257
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 312/800
# Train Loss: 0.0113, Validation Loss: 0.6027
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.8750
# Epoch 313/800
# Train Loss: 0.0115, Validation Loss: 0.6620
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 314/800
# Train Loss: 0.0114, Validation Loss: 0.7200
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 315/800
# Train Loss: 0.0105, Validation Loss: 0.6618
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.8750
# Epoch 316/800
# ...
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 76/800
# Train Loss: 0.0857, Validation Loss: 0.7776
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 77/800
# Train Loss: 0.0812, Validation Loss: 0.8185
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 78/800
# Train Loss: 0.0930, Validation Loss: 0.7393
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 79/800
# Train Loss: 0.0836, Validation Loss: 0.7957
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 80/800
# Train Loss: 0.0907, Validation Loss: 0.7541
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 81/800
# Train Loss: 0.0840, Validation Loss: 0.7676
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 82/800
# Train Loss: 0.0869, Validation Loss: 0.7891
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 83/800
# Train Loss: 0.0788, Validation Loss: 0.7284
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 84/800
# Train Loss: 0.0778, Validation Loss: 0.7786
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 85/800
# Train Loss: 0.0750, Validation Loss: 0.7421
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 86/800
# Train Loss: 0.0726, Validation Loss: 0.7682
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 87/800
# Train Loss: 0.0835, Validation Loss: 0.7372
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 88/800
# Train Loss: 0.0797, Validation Loss: 0.7336
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 89/800
# Train Loss: 0.0773, Validation Loss: 0.7853
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 90/800
# Train Loss: 0.0732, Validation Loss: 0.7367
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 91/800
# Train Loss: 0.0664, Validation Loss: 0.8384
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 92/800
# Train Loss: 0.0776, Validation Loss: 0.7257
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 93/800
# Train Loss: 0.0708, Validation Loss: 0.7971
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 94/800
# Train Loss: 0.0882, Validation Loss: 0.7329
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 95/800
# Train Loss: 0.0685, Validation Loss: 0.7065
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 96/800
# Train Loss: 0.0726, Validation Loss: 0.8310
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 97/800
# Train Loss: 0.0646, Validation Loss: 0.7025
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 98/800
# Train Loss: 0.0636, Validation Loss: 0.8134
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 99/800
# Train Loss: 0.0689, Validation Loss: 0.7136
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 100/800
# Train Loss: 0.0611, Validation Loss: 0.6841
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 101/800
# Train Loss: 0.0534, Validation Loss: 0.8603
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 102/800
# Train Loss: 0.0672, Validation Loss: 0.6763
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 103/800
# Train Loss: 0.0687, Validation Loss: 0.7327
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 104/800
# Train Loss: 0.0602, Validation Loss: 0.7858
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 105/800
# Train Loss: 0.0575, Validation Loss: 0.6799
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 106/800
# Train Loss: 0.0535, Validation Loss: 0.7844
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 107/800
# Train Loss: 0.0580, Validation Loss: 0.7213
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 108/800
# Train Loss: 0.0476, Validation Loss: 0.7961
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 109/800
# Train Loss: 0.0552, Validation Loss: 0.6861
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 110/800
# Train Loss: 0.0537, Validation Loss: 0.7828
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 111/800
# Train Loss: 0.0632, Validation Loss: 0.7225
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 112/800
# Train Loss: 0.0561, Validation Loss: 0.7139
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 113/800
# Train Loss: 0.0553, Validation Loss: 0.7929
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 114/800
# Train Loss: 0.0477, Validation Loss: 0.6951
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 115/800
# Train Loss: 0.0500, Validation Loss: 0.8010
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 116/800
# Train Loss: 0.0437, Validation Loss: 0.7019
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 117/800
# Train Loss: 0.0457, Validation Loss: 0.7536
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 118/800
# Train Loss: 0.0452, Validation Loss: 0.7204
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 119/800
# Train Loss: 0.0438, Validation Loss: 0.7208
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 120/800
# Train Loss: 0.0402, Validation Loss: 0.7303
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 121/800
# Train Loss: 0.0414, Validation Loss: 0.7568
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 122/800
# Train Loss: 0.0413, Validation Loss: 0.7440
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 123/800
# Train Loss: 0.0434, Validation Loss: 0.7223
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 124/800
# Train Loss: 0.0412, Validation Loss: 0.7233
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 125/800
# Train Loss: 0.0375, Validation Loss: 0.8109
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 126/800
# Train Loss: 0.0398, Validation Loss: 0.7035
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 127/800
# Train Loss: 0.0464, Validation Loss: 0.7587
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 128/800
# Train Loss: 0.0462, Validation Loss: 0.7927
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 129/800
# Train Loss: 0.0411, Validation Loss: 0.7164
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 130/800
# Train Loss: 0.0359, Validation Loss: 0.8683
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 131/800
# Train Loss: 0.0365, Validation Loss: 0.7195
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 132/800
# Train Loss: 0.0364, Validation Loss: 0.7832
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 133/800
# Train Loss: 0.0346, Validation Loss: 0.8083
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 134/800
# Train Loss: 0.0347, Validation Loss: 0.7189
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 135/800
# Train Loss: 0.0381, Validation Loss: 0.7598
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 136/800
# Train Loss: 0.0468, Validation Loss: 0.7802
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 137/800
# Train Loss: 0.0351, Validation Loss: 0.7072
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 138/800
# Train Loss: 0.0316, Validation Loss: 0.9555
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 139/800
# Train Loss: 0.0450, Validation Loss: 0.7235
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 140/800
# Train Loss: 0.0342, Validation Loss: 0.6992
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 141/800
# Train Loss: 0.0305, Validation Loss: 0.8933
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 142/800
# Train Loss: 0.0314, Validation Loss: 0.7194
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 143/800
# Train Loss: 0.0323, Validation Loss: 0.7237
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 144/800
# Train Loss: 0.0286, Validation Loss: 0.7951
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 145/800
# Train Loss: 0.0340, Validation Loss: 0.7724
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 146/800
# Train Loss: 0.0366, Validation Loss: 0.7310
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 147/800
# Train Loss: 0.0376, Validation Loss: 0.8473
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 148/800
# Train Loss: 0.0262, Validation Loss: 0.7042
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 149/800
# Train Loss: 0.0335, Validation Loss: 0.8145
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 150/800
# Train Loss: 0.0366, Validation Loss: 0.7356
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 151/800
# Train Loss: 0.0310, Validation Loss: 0.7036
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 152/800
# Train Loss: 0.0242, Validation Loss: 0.9461
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 153/800
# Train Loss: 0.0324, Validation Loss: 0.7271
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 154/800
# Train Loss: 0.0255, Validation Loss: 0.7285
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 155/800
# Train Loss: 0.0237, Validation Loss: 0.8030
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 156/800
# Train Loss: 0.0271, Validation Loss: 0.7743
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 157/800
# Train Loss: 0.0247, Validation Loss: 0.7271
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 158/800
# Train Loss: 0.0222, Validation Loss: 0.8366
# Train Accuracy: 1.0000, Validation Accuracy: 0.7500
# Max Validation Accuracy: 0.7500
# Epoch 159/800
# Train Loss: 0.0256, Validation Loss: 0.7596
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 160/800
# Train Loss: 0.0232, Validation Loss: 0.7439
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 161/800
# Train Loss: 0.0227, Validation Loss: 0.8177
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 162/800
# Train Loss: 0.0233, Validation Loss: 0.7621
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# Epoch 163/800
# Train Loss: 0.0234, Validation Loss: 0.7551
# Train Accuracy: 1.0000, Validation Accuracy: 0.5000
# Max Validation Accuracy: 0.7500
# Epoch 164/800
# Train Loss: 0.0230, Validation Loss: 0.8257
# Train Accuracy: 1.0000, Validation Accuracy: 0.6250
# Max Validation Accuracy: 0.7500
# /Users/mathilde/Documents/Bachelor-Thesis-Alzheimers-HGNN/functions.py:449: DeprecationWarning: invalid escape sequence '\m'
#   """The hypergraph convolutional operator from the `"Hypergraph Convolution
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 60
#      58     w_decay = params['weight_decay']
#      59 optimizer = torch.optim.Adam(model.parameters(), lr=parameters[0], weight_decay=w_decay)
# ---> 60 train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = m.train_GAT(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing=True, n_epochs=800)
#
# File ~/Documents/Bachelor-Thesis-Alzheimers-HGNN/models.py:191, in train_GAT(model, optimizer, criterion, w_decay, threshold, train_loader, valid_loader, parameters, test_loader, testing, n_epochs)
#     189 for epoch in range(n_epochs):
#     190     if testing:
# --> 191         train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy, test_accuracy = f.epochs_training(model, optimizer, criterion, train_loader, valid_loader, test_loader, testing, test_accuracy, train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy)
#     192         wandb.log({"Train Loss": train_losses[-1], "Train Accuracy": train_accuracies[-1], "Validation Loss": valid_losses[-1], "Validation Accuracy": valid_accuracies[-1], "Max Valid Accuracy": max_valid_accuracy, "Test Accuracy": test_accuracy})
#     193     else:
#
# File ~/Documents/Bachelor-Thesis-Alzheimers-HGNN/functions.py:634, in epochs_training(model, optimizer, criterion, train_loader, valid_loader, test_loader, testing, test_accuracy, train_losses, train_accuracies, valid_losses, valid_accuracies, max_valid_accuracy)
#     632 out = model(data.x, data.edge_index, data.batch)
#     633 loss = criterion(out, target)
# --> 634 loss.backward()
#     635 optimizer.step()
#     636 train_loss += criterion(out, target)
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/envs/alzheimers-cl/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:
